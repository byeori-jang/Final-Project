# %%
# ▶ 1. 필수 라이브러리
import pandas as pd
import numpy as np
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score
import warnings
warnings.filterwarnings('ignore')

# %%
# ▶ 2. 데이터 로딩
df = pd.read_csv('병합/New_unique_ID_Seg.csv', encoding='utf-8-sig')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400000 entries, 0 to 2399999
# Data columns (total 45 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ID                  object
#  1   _2순위카드이용금액          int64
#  2   이용금액_오프라인_B0M       int64
#  3   정상입금원금_B5M          int64
#  4   이용금액대               int64
#  5   이용금액_오프라인_R3M       int64
#  6   이용금액_오프라인_R6M       int64
#  7   정상입금원금_B2M          int64
#  8   _3순위업종_이용금액         int64
#  9   _2순위업종_이용금액         int64
#  10  _2순위쇼핑업종_이용금액       int64
#  11  최대이용금액_일시불_R12M     int64
#  12  _1순위업종_이용금액         int64
#  13  _3순위쇼핑업종_이용금액       int64
#  14  쇼핑_도소매_이용금액         int64
#  15  이용건수_오프라인_R6M       int64
#  16  _1순위교통업종_이용금액       int64
#  17  연체입금원금_B0M          int64
#  18  청구금액_R6M            int64
#  19  청구금액_B0             int64
#  20  평잔_일시불_6M           int64
#  21  월중평잔_일시불            int64
#  22  잔액_일시불_B0M          int64
#  23  입회일자_신용             int64
#  24  최종카드발급경과월           int64
#  25  _1순위카드이용건수          int64
#  26  월상환론한도금액            int64
#  27  CA한도금액              int64
#  28  카드이용한도금액_B2M        int64
#  29  연체입금원금_B5M          int64
#  30  연속유실적개월수_기본_24M_카드  int64
#  31  이용금액_체크_R12M        int64
#  32  할부금액_무이자_3M_R12M    int64
#  33  최대이용금액_체크_R12M      int64
#  34  연체입금원금_B2M          int64
#  35  탈회횟수_발급1년이내         int64
#  36  _2순위신용체크구분          object
#  37  이용금액_선결제_B0M        int64
#  38  이용금액_할부_무이자_R12M    int64
#  39  이용개월수_할부_무이자_R6M    int64
#  40  선입금원금_B5M           int64
#  41  최종이용일자_CA_년         int64
#  42  이용금액_CA_R3M         int64
#  43  할인금액_청구서_B0M        int64
#  44  Segment             object
# dtypes: int64(42), object(3)
# memory usage: 824.0+ MB

# %%
df['_2순위신용체크구분'].value_counts()
# Out:
# _2순위신용체크구분
# 기타    958115
# 신용    873447
# 체크    568438
# Name: count, dtype: int64

# %%
# ▶ 3. y_vif 생성 (Segment → 숫자 라벨로)
le = LabelEncoder()
y_vif = le.fit_transform(df['Segment'])

# %%
# ▶ 4. X_selected 생성 (불필요한 컬럼 제거)
X_selected = df.drop(columns=['Segment', 'ID'])
X_vif = X_selected.copy()

# %%
# ▶ cat_features 추출 (문자열형 컬럼 목록)
cat_features = X_vif.select_dtypes(include=['object']).columns.tolist()

# %%
# ▶ 5. 교차검증 수동 구현 (CatBoost 안정성 확보)
def evaluate_cv_score_manual(X_input, y_input, cat_features, cv=3):
    skf = StratifiedKFold(n_splits=cv, shuffle=True, random_state=42)
    scores = []

    for fold, (train_idx, valid_idx) in enumerate(skf.split(X_input, y_input), 1):
        X_train, X_val = X_input.iloc[train_idx], X_input.iloc[valid_idx]
        y_train, y_val = y_input[train_idx], y_input[valid_idx]

        model = CatBoostClassifier(
            loss_function="MultiClass",
            eval_metric="MultiClass",
            task_type="GPU",
            learning_rate=0.01,
            iterations=70000,
            early_stopping_rounds=3000,
            l2_leaf_reg=50,
            random_seed=42,
            od_type="Iter",
            depth=5,
            border_count=64,
            verbose=1000
        )

        model.fit(X_train, y_train, eval_set=(X_val, y_val), cat_features=cat_features, use_best_model=True)
        preds = model.predict(X_val)
        score = f1_score(y_val, preds, average='micro')
        scores.append(score)

        print(f"• Fold {fold}: {score:.4f}")

    print(f"\n✅ 평균 F1_micro 스코어: {np.mean(scores):.4f}")
    return np.mean(scores)

# %%
# 실행
evaluate_cv_score_manual(X_vif, y_vif, cat_features)
# Out:
# 0:	learn: 1.5800731	test: 1.5800939	best: 1.5800939 (0)	total: 90.2ms	remaining: 1h 45m 14s
# 1000:	learn: 0.2913911	test: 0.2926447	best: 0.2926447 (1000)	total: 33.2s	remaining: 38m 7s
# 2000:	learn: 0.2756604	test: 0.2772502	best: 0.2772502 (2000)	total: 1m 7s	remaining: 38m 17s
# 3000:	learn: 0.2677993	test: 0.2696370	best: 0.2696370 (3000)	total: 1m 41s	remaining: 37m 47s
# 4000:	learn: 0.2626479	test: 0.2647543	best: 0.2647543 (4000)	total: 2m 15s	remaining: 37m 22s
# 5000:	learn: 0.2588649	test: 0.2612537	best: 0.2612537 (5000)	total: 2m 50s	remaining: 36m 52s
# 6000:	learn: 0.2557832	test: 0.2584523	best: 0.2584523 (6000)	total: 3m 24s	remaining: 36m 17s
# 7000:	learn: 0.2532433	test: 0.2562046	best: 0.2562046 (7000)	total: 3m 58s	remaining: 35m 44s
# 8000:	learn: 0.2510970	test: 0.2543523	best: 0.2543523 (8000)	total: 4m 32s	remaining: 35m 14s
# 9000:	learn: 0.2492037	test: 0.2527477	best: 0.2527477 (9000)	total: 5m 6s	remaining: 34m 40s
# 10000:	learn: 0.2474979	test: 0.2513334	best: 0.2513334 (10000)	total: 5m 39s	remaining: 33m 55s
# 11000:	learn: 0.2459521	test: 0.2500574	best: 0.2500574 (11000)	total: 6m 10s	remaining: 33m 9s
# 12000:	learn: 0.2445615	test: 0.2489427	best: 0.2489427 (12000)	total: 6m 42s	remaining: 32m 26s
# 13000:	learn: 0.2432670	test: 0.2479231	best: 0.2479231 (13000)	total: 7m 14s	remaining: 31m 46s
# 14000:	learn: 0.2420801	test: 0.2470045	best: 0.2470045 (14000)	total: 7m 46s	remaining: 31m 7s
# 15000:	learn: 0.2409682	test: 0.2461496	best: 0.2461496 (15000)	total: 8m 20s	remaining: 30m 36s
# 16000:	learn: 0.2399193	test: 0.2453543	best: 0.2453543 (16000)	total: 8m 56s	remaining: 30m 10s
# 17000:	learn: 0.2389305	test: 0.2446302	best: 0.2446302 (17000)	total: 9m 32s	remaining: 29m 44s
# 18000:	learn: 0.2379935	test: 0.2439589	best: 0.2439589 (18000)	total: 10m 8s	remaining: 29m 17s
# 19000:	learn: 0.2370993	test: 0.2433079	best: 0.2433079 (19000)	total: 10m 44s	remaining: 28m 50s
# 20000:	learn: 0.2362657	test: 0.2427194	best: 0.2427194 (20000)	total: 11m 20s	remaining: 28m 20s
# 21000:	learn: 0.2354539	test: 0.2421466	best: 0.2421466 (21000)	total: 11m 55s	remaining: 27m 48s
# 22000:	learn: 0.2346693	test: 0.2416058	best: 0.2416058 (22000)	total: 12m 27s	remaining: 27m 11s
# 23000:	learn: 0.2339039	test: 0.2410750	best: 0.2410750 (23000)	total: 12m 59s	remaining: 26m 33s
# 24000:	learn: 0.2331664	test: 0.2405719	best: 0.2405719 (24000)	total: 13m 32s	remaining: 25m 56s
# 25000:	learn: 0.2324858	test: 0.2401172	best: 0.2401172 (25000)	total: 14m 4s	remaining: 25m 19s
# 26000:	learn: 0.2318110	test: 0.2396664	best: 0.2396664 (26000)	total: 14m 36s	remaining: 24m 42s
# 27000:	learn: 0.2311402	test: 0.2392104	best: 0.2392104 (27000)	total: 15m 8s	remaining: 24m 6s
# 28000:	learn: 0.2305082	test: 0.2387875	best: 0.2387875 (28000)	total: 15m 40s	remaining: 23m 31s
# 29000:	learn: 0.2298871	test: 0.2383776	best: 0.2383776 (29000)	total: 16m 15s	remaining: 22m 58s
# 30000:	learn: 0.2292714	test: 0.2379759	best: 0.2379759 (30000)	total: 16m 50s	remaining: 22m 26s
# 31000:	learn: 0.2286898	test: 0.2376075	best: 0.2376075 (31000)	total: 17m 28s	remaining: 21m 58s
# 32000:	learn: 0.2281018	test: 0.2372260	best: 0.2372260 (32000)	total: 18m 3s	remaining: 21m 26s
# 33000:	learn: 0.2275380	test: 0.2368704	best: 0.2368704 (33000)	total: 18m 38s	remaining: 20m 54s
# 34000:	learn: 0.2269672	test: 0.2365006	best: 0.2365006 (34000)	total: 19m 10s	remaining: 20m 18s
# 35000:	learn: 0.2264218	test: 0.2361483	best: 0.2361483 (35000)	total: 19m 44s	remaining: 19m 44s
# 36000:	learn: 0.2258779	test: 0.2357997	best: 0.2357997 (36000)	total: 20m 18s	remaining: 19m 11s
# 37000:	learn: 0.2253609	test: 0.2354770	best: 0.2354770 (37000)	total: 20m 52s	remaining: 18m 37s
# 38000:	learn: 0.2248316	test: 0.2351462	best: 0.2351462 (38000)	total: 21m 27s	remaining: 18m 4s
# 39000:	learn: 0.2243291	test: 0.2348328	best: 0.2348328 (39000)	total: 22m 2s	remaining: 17m 31s
# 40000:	learn: 0.2238289	test: 0.2345228	best: 0.2345228 (40000)	total: 22m 37s	remaining: 16m 58s
# 41000:	learn: 0.2233341	test: 0.2342192	best: 0.2342192 (41000)	total: 23m 12s	remaining: 16m 24s
# 42000:	learn: 0.2228477	test: 0.2339240	best: 0.2339240 (42000)	total: 23m 47s	remaining: 15m 51s
# 43000:	learn: 0.2223715	test: 0.2336292	best: 0.2336292 (42999)	total: 24m 21s	remaining: 15m 17s
# 44000:	learn: 0.2219129	test: 0.2333498	best: 0.2333497 (43999)	total: 24m 55s	remaining: 14m 43s
# 45000:	learn: 0.2214586	test: 0.2330840	best: 0.2330840 (45000)	total: 25m 29s	remaining: 14m 9s
# 46000:	learn: 0.2209949	test: 0.2328054	best: 0.2328054 (46000)	total: 26m 4s	remaining: 13m 36s
# 47000:	learn: 0.2205383	test: 0.2325273	best: 0.2325273 (47000)	total: 26m 38s	remaining: 13m 2s
# 48000:	learn: 0.2201062	test: 0.2322735	best: 0.2322735 (48000)	total: 27m 13s	remaining: 12m 28s
# 49000:	learn: 0.2196739	test: 0.2320171	best: 0.2320171 (49000)	total: 27m 45s	remaining: 11m 53s
# 50000:	learn: 0.2192492	test: 0.2317641	best: 0.2317641 (50000)	total: 28m 18s	remaining: 11m 19s
# 51000:	learn: 0.2188312	test: 0.2315193	best: 0.2315193 (51000)	total: 28m 53s	remaining: 10m 45s
# 52000:	learn: 0.2184119	test: 0.2312710	best: 0.2312710 (52000)	total: 29m 27s	remaining: 10m 11s
# 53000:	learn: 0.2180056	test: 0.2310355	best: 0.2310355 (53000)	total: 30m 2s	remaining: 9m 38s
# 54000:	learn: 0.2175963	test: 0.2307953	best: 0.2307953 (54000)	total: 30m 36s	remaining: 9m 4s
# 55000:	learn: 0.2171790	test: 0.2305537	best: 0.2305537 (55000)	total: 31m 11s	remaining: 8m 30s
# 56000:	learn: 0.2167691	test: 0.2303132	best: 0.2303132 (56000)	total: 31m 46s	remaining: 7m 56s
# 57000:	learn: 0.2163709	test: 0.2300854	best: 0.2300854 (57000)	total: 32m 21s	remaining: 7m 22s
# 58000:	learn: 0.2159671	test: 0.2298600	best: 0.2298600 (58000)	total: 32m 54s	remaining: 6m 48s
# 59000:	learn: 0.2155754	test: 0.2296370	best: 0.2296370 (59000)	total: 33m 26s	remaining: 6m 14s
# 60000:	learn: 0.2151845	test: 0.2294167	best: 0.2294167 (60000)	total: 33m 58s	remaining: 5m 39s
# 61000:	learn: 0.2148021	test: 0.2291980	best: 0.2291980 (61000)	total: 34m 32s	remaining: 5m 5s
# 62000:	learn: 0.2144094	test: 0.2289716	best: 0.2289716 (62000)	total: 35m 6s	remaining: 4m 31s
# 63000:	learn: 0.2140309	test: 0.2287621	best: 0.2287621 (63000)	total: 35m 41s	remaining: 3m 57s
# 64000:	learn: 0.2136454	test: 0.2285405	best: 0.2285404 (63999)	total: 36m 16s	remaining: 3m 24s
# 65000:	learn: 0.2132734	test: 0.2283334	best: 0.2283334 (65000)	total: 36m 51s	remaining: 2m 50s
# 66000:	learn: 0.2129101	test: 0.2281266	best: 0.2281266 (65998)	total: 37m 26s	remaining: 2m 16s
# 67000:	learn: 0.2125484	test: 0.2279250	best: 0.2279250 (67000)	total: 38m 1s	remaining: 1m 42s
# 68000:	learn: 0.2121877	test: 0.2277243	best: 0.2277241 (67998)	total: 38m 35s	remaining: 1m 8s
# 69000:	learn: 0.2118291	test: 0.2275253	best: 0.2275253 (69000)	total: 39m 10s	remaining: 34s
# 69999:	learn: 0.2114657	test: 0.2273206	best: 0.2273206 (69999)	total: 39m 45s	remaining: 0us
# bestTest = 0.2273205664
# bestIteration = 69999
# • Fold 1: 0.9106
# 0:	learn: 1.5800842	test: 1.5800703	best: 1.5800703 (0)	total: 34.4ms	remaining: 40m 10s
# 1000:	learn: 0.2921913	test: 0.2923085	best: 0.2923085 (1000)	total: 37s	remaining: 42m 33s
# 2000:	learn: 0.2764924	test: 0.2769232	best: 0.2769232 (2000)	total: 1m 13s	remaining: 41m 30s
# 3000:	learn: 0.2687630	test: 0.2695125	best: 0.2695125 (3000)	total: 1m 49s	remaining: 40m 44s
# 4000:	learn: 0.2636705	test: 0.2647271	best: 0.2647271 (4000)	total: 2m 25s	remaining: 39m 55s
# 5000:	learn: 0.2599370	test: 0.2613226	best: 0.2613226 (5000)	total: 3m	remaining: 39m 7s
# 6000:	learn: 0.2569482	test: 0.2586509	best: 0.2586509 (6000)	total: 3m 37s	remaining: 38m 35s
# 7000:	learn: 0.2544410	test: 0.2564363	best: 0.2564363 (7000)	total: 4m 12s	remaining: 37m 52s
# 8000:	learn: 0.2523359	test: 0.2546245	best: 0.2546245 (8000)	total: 4m 47s	remaining: 37m 11s
# 9000:	learn: 0.2504539	test: 0.2530206	best: 0.2530206 (9000)	total: 5m 22s	remaining: 36m 27s
# 10000:	learn: 0.2487580	test: 0.2516117	best: 0.2516117 (10000)	total: 5m 55s	remaining: 35m 35s
# 11000:	learn: 0.2472359	test: 0.2503507	best: 0.2503507 (11000)	total: 6m 31s	remaining: 34m 58s
# 12000:	learn: 0.2458456	test: 0.2492157	best: 0.2492157 (12000)	total: 7m 6s	remaining: 34m 20s
# 13000:	learn: 0.2445899	test: 0.2482078	best: 0.2482078 (13000)	total: 7m 39s	remaining: 33m 33s
# 14000:	learn: 0.2434411	test: 0.2473041	best: 0.2473041 (14000)	total: 8m 13s	remaining: 32m 55s
# 15000:	learn: 0.2423838	test: 0.2464835	best: 0.2464835 (15000)	total: 8m 45s	remaining: 32m 7s
# 16000:	learn: 0.2413816	test: 0.2457145	best: 0.2457145 (16000)	total: 9m 17s	remaining: 31m 21s
# 17000:	learn: 0.2404530	test: 0.2450097	best: 0.2450097 (16999)	total: 9m 52s	remaining: 30m 47s
# 18000:	learn: 0.2395820	test: 0.2443574	best: 0.2443574 (18000)	total: 10m 26s	remaining: 30m 9s
# 19000:	learn: 0.2387378	test: 0.2437279	best: 0.2437279 (19000)	total: 10m 57s	remaining: 29m 24s
# 20000:	learn: 0.2379128	test: 0.2431195	best: 0.2431195 (20000)	total: 11m 28s	remaining: 28m 41s
# 21000:	learn: 0.2371471	test: 0.2425668	best: 0.2425668 (21000)	total: 12m	remaining: 28m
# 22000:	learn: 0.2364313	test: 0.2420528	best: 0.2420528 (22000)	total: 12m 31s	remaining: 27m 20s
# 23000:	learn: 0.2357000	test: 0.2415411	best: 0.2415411 (23000)	total: 13m 3s	remaining: 26m 40s
# 24000:	learn: 0.2350143	test: 0.2410680	best: 0.2410680 (24000)	total: 13m 35s	remaining: 26m 2s
# 25000:	learn: 0.2343457	test: 0.2406061	best: 0.2406061 (25000)	total: 14m 7s	remaining: 25m 24s
# 26000:	learn: 0.2336685	test: 0.2401300	best: 0.2401300 (26000)	total: 14m 39s	remaining: 24m 48s
# 27000:	learn: 0.2330324	test: 0.2396973	best: 0.2396973 (27000)	total: 15m 13s	remaining: 24m 15s
# 28000:	learn: 0.2324166	test: 0.2392814	best: 0.2392814 (28000)	total: 15m 46s	remaining: 23m 40s
# 29000:	learn: 0.2317904	test: 0.2388589	best: 0.2388589 (29000)	total: 16m 18s	remaining: 23m 3s
# 30000:	learn: 0.2312092	test: 0.2384783	best: 0.2384783 (30000)	total: 16m 50s	remaining: 22m 26s
# 31000:	learn: 0.2305971	test: 0.2380694	best: 0.2380694 (31000)	total: 17m 22s	remaining: 21m 50s
# 32000:	learn: 0.2300235	test: 0.2376906	best: 0.2376906 (32000)	total: 17m 54s	remaining: 21m 15s
# 33000:	learn: 0.2294607	test: 0.2373199	best: 0.2373199 (33000)	total: 18m 31s	remaining: 20m 46s
# 34000:	learn: 0.2289240	test: 0.2369754	best: 0.2369754 (34000)	total: 19m 12s	remaining: 20m 20s
# 35000:	learn: 0.2283924	test: 0.2366400	best: 0.2366400 (35000)	total: 19m 55s	remaining: 19m 55s
# 36000:	learn: 0.2278543	test: 0.2362971	best: 0.2362971 (36000)	total: 20m 30s	remaining: 19m 22s
# 37000:	learn: 0.2273374	test: 0.2359709	best: 0.2359709 (37000)	total: 21m 5s	remaining: 18m 48s
# 38000:	learn: 0.2268220	test: 0.2356430	best: 0.2356430 (38000)	total: 21m 40s	remaining: 18m 15s
# 39000:	learn: 0.2263216	test: 0.2353341	best: 0.2353341 (39000)	total: 22m 15s	remaining: 17m 41s
# 40000:	learn: 0.2258365	test: 0.2350409	best: 0.2350409 (40000)	total: 22m 50s	remaining: 17m 7s
# 41000:	learn: 0.2253416	test: 0.2347387	best: 0.2347387 (41000)	total: 23m 24s	remaining: 16m 33s
# 42000:	learn: 0.2248651	test: 0.2344508	best: 0.2344508 (42000)	total: 23m 57s	remaining: 15m 58s
# 43000:	learn: 0.2243927	test: 0.2341616	best: 0.2341616 (43000)	total: 24m 32s	remaining: 15m 24s
# 44000:	learn: 0.2239251	test: 0.2338754	best: 0.2338754 (44000)	total: 25m 8s	remaining: 14m 51s
# 45000:	learn: 0.2234537	test: 0.2335911	best: 0.2335911 (45000)	total: 25m 43s	remaining: 14m 17s
# 46000:	learn: 0.2229871	test: 0.2333067	best: 0.2333067 (46000)	total: 26m 16s	remaining: 13m 42s
# 47000:	learn: 0.2225314	test: 0.2330386	best: 0.2330385 (46999)	total: 26m 48s	remaining: 13m 6s
# 48000:	learn: 0.2220846	test: 0.2327746	best: 0.2327746 (48000)	total: 27m 19s	remaining: 12m 31s
# 49000:	learn: 0.2216416	test: 0.2325136	best: 0.2325136 (49000)	total: 27m 53s	remaining: 11m 57s
# 50000:	learn: 0.2211878	test: 0.2322394	best: 0.2322394 (50000)	total: 28m 29s	remaining: 11m 23s
# 51000:	learn: 0.2207458	test: 0.2319827	best: 0.2319827 (50999)	total: 29m 5s	remaining: 10m 50s
# 52000:	learn: 0.2203146	test: 0.2317258	best: 0.2317258 (52000)	total: 29m 40s	remaining: 10m 16s
# 53000:	learn: 0.2198849	test: 0.2314727	best: 0.2314727 (53000)	total: 30m 16s	remaining: 9m 42s
# 54000:	learn: 0.2194601	test: 0.2312247	best: 0.2312246 (53998)	total: 30m 51s	remaining: 9m 8s
# 55000:	learn: 0.2190283	test: 0.2309708	best: 0.2309708 (55000)	total: 31m 27s	remaining: 8m 34s
# 56000:	learn: 0.2185941	test: 0.2307160	best: 0.2307159 (55999)	total: 32m 2s	remaining: 8m
# 57000:	learn: 0.2181711	test: 0.2304693	best: 0.2304693 (56998)	total: 32m 34s	remaining: 7m 25s
# 58000:	learn: 0.2177521	test: 0.2302279	best: 0.2302279 (58000)	total: 33m 6s	remaining: 6m 50s
# 59000:	learn: 0.2173350	test: 0.2299860	best: 0.2299860 (59000)	total: 33m 37s	remaining: 6m 16s
# 60000:	learn: 0.2169332	test: 0.2297562	best: 0.2297562 (59999)	total: 34m 9s	remaining: 5m 41s
# 61000:	learn: 0.2165293	test: 0.2295292	best: 0.2295292 (61000)	total: 34m 40s	remaining: 5m 6s
# 62000:	learn: 0.2161320	test: 0.2292958	best: 0.2292956 (61999)	total: 35m 12s	remaining: 4m 32s
# 63000:	learn: 0.2157311	test: 0.2290685	best: 0.2290685 (63000)	total: 35m 45s	remaining: 3m 58s
# 64000:	learn: 0.2153306	test: 0.2288435	best: 0.2288435 (64000)	total: 36m 18s	remaining: 3m 24s
# 65000:	learn: 0.2149406	test: 0.2286249	best: 0.2286249 (65000)	total: 36m 50s	remaining: 2m 49s
# 66000:	learn: 0.2145567	test: 0.2284096	best: 0.2284096 (66000)	total: 37m 22s	remaining: 2m 15s
# 67000:	learn: 0.2141733	test: 0.2281965	best: 0.2281965 (67000)	total: 37m 54s	remaining: 1m 41s
# 68000:	learn: 0.2137796	test: 0.2279754	best: 0.2279754 (68000)	total: 38m 25s	remaining: 1m 7s
# 69000:	learn: 0.2134018	test: 0.2277640	best: 0.2277640 (69000)	total: 38m 57s	remaining: 33.8s
# 69999:	learn: 0.2130243	test: 0.2275540	best: 0.2275540 (69999)	total: 39m 29s	remaining: 0us
# bestTest = 0.2275540234
# bestIteration = 69999
# • Fold 2: 0.9105
# 0:	learn: 1.5800878	test: 1.5800823	best: 1.5800823 (0)	total: 31.5ms	remaining: 36m 44s
# 1000:	learn: 0.2917395	test: 0.2917820	best: 0.2917820 (1000)	total: 33.2s	remaining: 38m 11s
# 2000:	learn: 0.2760337	test: 0.2765112	best: 0.2765112 (2000)	total: 1m 5s	remaining: 36m 57s
# 3000:	learn: 0.2681692	test: 0.2689979	best: 0.2689979 (3000)	total: 1m 36s	remaining: 36m 1s
# 4000:	learn: 0.2630749	test: 0.2642450	best: 0.2642450 (4000)	total: 2m 8s	remaining: 35m 20s
# 5000:	learn: 0.2593204	test: 0.2608268	best: 0.2608268 (5000)	total: 2m 40s	remaining: 34m 44s
# 6000:	learn: 0.2562887	test: 0.2581232	best: 0.2581232 (6000)	total: 3m 13s	remaining: 34m 18s
# 7000:	learn: 0.2537571	test: 0.2559201	best: 0.2559201 (7000)	total: 3m 44s	remaining: 33m 40s
# 8000:	learn: 0.2515231	test: 0.2539955	best: 0.2539955 (8000)	total: 4m 16s	remaining: 33m 4s
# 9000:	learn: 0.2496210	test: 0.2523866	best: 0.2523866 (9000)	total: 4m 47s	remaining: 32m 28s
# 10000:	learn: 0.2479098	test: 0.2509745	best: 0.2509745 (10000)	total: 5m 19s	remaining: 31m 57s
# 11000:	learn: 0.2463210	test: 0.2496687	best: 0.2496687 (11000)	total: 5m 51s	remaining: 31m 23s
# 12000:	learn: 0.2449374	test: 0.2485631	best: 0.2485631 (12000)	total: 6m 22s	remaining: 30m 49s
# 13000:	learn: 0.2436498	test: 0.2475462	best: 0.2475462 (13000)	total: 6m 53s	remaining: 30m 14s
# 14000:	learn: 0.2424759	test: 0.2466407	best: 0.2466407 (14000)	total: 7m 25s	remaining: 29m 43s
# 15000:	learn: 0.2414097	test: 0.2458353	best: 0.2458353 (15000)	total: 7m 57s	remaining: 29m 9s
# 16000:	learn: 0.2404255	test: 0.2450971	best: 0.2450971 (16000)	total: 8m 28s	remaining: 28m 37s
# 17000:	learn: 0.2394795	test: 0.2443911	best: 0.2443911 (17000)	total: 9m 1s	remaining: 28m 7s
# 18000:	learn: 0.2385847	test: 0.2437357	best: 0.2437357 (18000)	total: 9m 33s	remaining: 27m 37s
# 19000:	learn: 0.2377147	test: 0.2430967	best: 0.2430967 (19000)	total: 10m 5s	remaining: 27m 5s
# 20000:	learn: 0.2368618	test: 0.2424771	best: 0.2424771 (20000)	total: 10m 37s	remaining: 26m 34s
# 21000:	learn: 0.2360628	test: 0.2419117	best: 0.2419117 (21000)	total: 11m 10s	remaining: 26m 4s
# 22000:	learn: 0.2353145	test: 0.2413920	best: 0.2413920 (22000)	total: 11m 42s	remaining: 25m 31s
# 23000:	learn: 0.2345713	test: 0.2408786	best: 0.2408786 (23000)	total: 12m 13s	remaining: 24m 59s
# 24000:	learn: 0.2338450	test: 0.2403779	best: 0.2403779 (23999)	total: 12m 45s	remaining: 24m 27s
# 25000:	learn: 0.2331253	test: 0.2398853	best: 0.2398853 (25000)	total: 13m 17s	remaining: 23m 54s
# 26000:	learn: 0.2324503	test: 0.2394284	best: 0.2394284 (26000)	total: 13m 48s	remaining: 23m 22s
# 27000:	learn: 0.2317815	test: 0.2389751	best: 0.2389751 (27000)	total: 14m 20s	remaining: 22m 50s
# 28000:	learn: 0.2311492	test: 0.2385561	best: 0.2385561 (28000)	total: 14m 52s	remaining: 22m 18s
# 29000:	learn: 0.2305137	test: 0.2381331	best: 0.2381331 (29000)	total: 15m 24s	remaining: 21m 47s
# 30000:	learn: 0.2299014	test: 0.2377255	best: 0.2377255 (30000)	total: 15m 56s	remaining: 21m 15s
# 31000:	learn: 0.2292942	test: 0.2373262	best: 0.2373262 (31000)	total: 16m 28s	remaining: 20m 43s
# 32000:	learn: 0.2286940	test: 0.2369425	best: 0.2369425 (32000)	total: 16m 59s	remaining: 20m 11s
# 33000:	learn: 0.2281116	test: 0.2365679	best: 0.2365679 (33000)	total: 17m 31s	remaining: 19m 38s
# 34000:	learn: 0.2275375	test: 0.2361987	best: 0.2361987 (34000)	total: 18m 3s	remaining: 19m 6s
# 35000:	learn: 0.2269625	test: 0.2358342	best: 0.2358342 (35000)	total: 18m 35s	remaining: 18m 35s
# 36000:	learn: 0.2264062	test: 0.2354891	best: 0.2354891 (36000)	total: 19m 8s	remaining: 18m 4s
# 37000:	learn: 0.2258579	test: 0.2351464	best: 0.2351464 (37000)	total: 19m 40s	remaining: 17m 33s
# 38000:	learn: 0.2253199	test: 0.2348147	best: 0.2348147 (38000)	total: 20m 13s	remaining: 17m 1s
# 39000:	learn: 0.2247927	test: 0.2344872	best: 0.2344872 (39000)	total: 20m 45s	remaining: 16m 29s
# 40000:	learn: 0.2242763	test: 0.2341729	best: 0.2341729 (40000)	total: 21m 16s	remaining: 15m 57s
# 41000:	learn: 0.2237697	test: 0.2338622	best: 0.2338622 (40999)	total: 21m 48s	remaining: 15m 25s
# 42000:	learn: 0.2232705	test: 0.2335633	best: 0.2335633 (42000)	total: 22m 20s	remaining: 14m 53s
# 43000:	learn: 0.2227740	test: 0.2332627	best: 0.2332627 (42999)	total: 22m 53s	remaining: 14m 22s
# 44000:	learn: 0.2222909	test: 0.2329732	best: 0.2329732 (44000)	total: 23m 25s	remaining: 13m 50s
# 45000:	learn: 0.2218018	test: 0.2326807	best: 0.2326807 (45000)	total: 23m 56s	remaining: 13m 18s
# 46000:	learn: 0.2213284	test: 0.2324013	best: 0.2324013 (46000)	total: 24m 29s	remaining: 12m 46s
# 47000:	learn: 0.2208588	test: 0.2321230	best: 0.2321230 (47000)	total: 25m 1s	remaining: 12m 14s
# 48000:	learn: 0.2203885	test: 0.2318470	best: 0.2318470 (48000)	total: 25m 33s	remaining: 11m 43s
# 49000:	learn: 0.2199335	test: 0.2315841	best: 0.2315840 (48999)	total: 26m 5s	remaining: 11m 11s
# 50000:	learn: 0.2194811	test: 0.2313193	best: 0.2313193 (50000)	total: 26m 38s	remaining: 10m 39s
# 51000:	learn: 0.2190296	test: 0.2310518	best: 0.2310518 (51000)	total: 27m 10s	remaining: 10m 7s
# 52000:	learn: 0.2185912	test: 0.2307998	best: 0.2307998 (52000)	total: 27m 42s	remaining: 9m 35s
# 53000:	learn: 0.2181481	test: 0.2305431	best: 0.2305431 (53000)	total: 28m 14s	remaining: 9m 3s
# 54000:	learn: 0.2177066	test: 0.2302840	best: 0.2302840 (54000)	total: 28m 45s	remaining: 8m 31s
# 55000:	learn: 0.2172807	test: 0.2300429	best: 0.2300429 (55000)	total: 29m 17s	remaining: 7m 59s
# 56000:	learn: 0.2168573	test: 0.2297998	best: 0.2297998 (56000)	total: 29m 49s	remaining: 7m 27s
# 57000:	learn: 0.2164383	test: 0.2295610	best: 0.2295610 (57000)	total: 30m 21s	remaining: 6m 55s
# 58000:	learn: 0.2160292	test: 0.2293348	best: 0.2293348 (57998)	total: 30m 54s	remaining: 6m 23s
# 59000:	learn: 0.2156244	test: 0.2291098	best: 0.2291098 (59000)	total: 31m 27s	remaining: 5m 51s
# 60000:	learn: 0.2152073	test: 0.2288701	best: 0.2288701 (60000)	total: 32m	remaining: 5m 20s
# 61000:	learn: 0.2148096	test: 0.2286464	best: 0.2286464 (61000)	total: 32m 33s	remaining: 4m 48s
# 62000:	learn: 0.2144093	test: 0.2284229	best: 0.2284229 (62000)	total: 33m 6s	remaining: 4m 16s
# 63000:	learn: 0.2140214	test: 0.2282076	best: 0.2282076 (63000)	total: 33m 38s	remaining: 3m 44s
# 64000:	learn: 0.2136396	test: 0.2279958	best: 0.2279958 (64000)	total: 34m 11s	remaining: 3m 12s
# 65000:	learn: 0.2132476	test: 0.2277781	best: 0.2277781 (65000)	total: 34m 44s	remaining: 2m 40s
# 66000:	learn: 0.2128563	test: 0.2275592	best: 0.2275591 (65999)	total: 35m 17s	remaining: 2m 8s
# 67000:	learn: 0.2124671	test: 0.2273449	best: 0.2273449 (66999)	total: 35m 49s	remaining: 1m 36s
# 68000:	learn: 0.2120802	test: 0.2271352	best: 0.2271352 (68000)	total: 36m 22s	remaining: 1m 4s
# 69000:	learn: 0.2116987	test: 0.2269245	best: 0.2269245 (69000)	total: 36m 54s	remaining: 32.1s
# 69999:	learn: 0.2113276	test: 0.2267198	best: 0.2267198 (69999)	total: 37m 26s	remaining: 0us
# bestTest = 0.2267198242
# bestIteration = 69999
# • Fold 3: 0.9111
#
# ✅ 평균 F1_micro 스코어: 0.9107
# np.float64(0.91073375)

# %% [raw]
# • Fold 1: 0.9106
# • Fold 2: 0.9105
# • Fold 3: 0.9111
# ✅ 평균 F1_micro 스코어: 0.9107

# %%
X_vif.to_csv(f'New unique/X_vif.csv', index=False)
pd.DataFrame({'Segment_encoded': y_vif}).to_csv(f'New unique/y_vif_encoded.csv', index=False)

# %%
import pickle

# ▶ cat_features: 범주형 변수 인덱스
with open(f'New unique/cat_features.pkl', 'rb') as f:
    cat_features = pickle.load(f)

# ▶ label_encoder: 숫자 → 문자 라벨 매핑용
with open(f'New unique/label_encoder.pkl', 'rb') as f:
    le = pickle.load(f)

# ▶ feature_columns: test 데이터 컬럼 순서 일치용
with open(f'New unique/feature_columns.pkl', 'rb') as f:
    feature_cols = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[24], line 5
#       3 # ▶ cat_features: 범주형 변수 인덱스
#       4 with open(f'New unique/cat_features.pkl', 'rb') as f:
# ----> 5     cat_features = pickle.load(f)
#       7 # ▶ label_encoder: 숫자 → 문자 라벨 매핑용
#       8 with open(f'New unique/label_encoder.pkl', 'rb') as f:
#
# EOFError: Ran out of input

# %%
import pickle
import os

# 저장 폴더 경로
save_path = 'New unique'
os.makedirs(save_path, exist_ok=True)

# 1. 범주형 인덱스 저장
with open(os.path.join(save_path, 'cat_features.pkl'), 'wb') as f:
    pickle.dump(cat_features, f)

# 2. LabelEncoder 저장
with open(os.path.join(save_path, 'label_encoder.pkl'), 'wb') as f:
    pickle.dump(le, f)

# 3. Feature 컬럼 순서 저장
with open(os.path.join(save_path, 'feature_columns.pkl'), 'wb') as f:
    pickle.dump(X_vif.columns.tolist(), f)

print("✅ 모든 pickle 파일 저장 완료!")
# Out:
# ✅ 모든 pickle 파일 저장 완료!
