# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import gc

# 그래프 설정
sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 13
plt.rcParams['axes.unicode_minus'] = False

# %%
# 데이터프레임을 넣고 column별 특성 및 결측값, 고유값들을 확인하는 함수를 작성해본다.
# 필수는 아니지만 전체적인 흐름을 파악하기 쉬워진다.

def resumetable(df, n):
    print(f'데이터셋 크기: {df.shape}')                                # 데이터프레임의 전체 크기(행, 열) 출력

    summary = pd.DataFrame(df.dtypes, columns=['데이터 타입'])         # 각 피처의 데이터 타입을 가져와 데이터프레임으로 생성
    summary = summary.reset_index()                                    # 인덱스를 초기화하여 컬럼으로 변환
    summary = summary.rename(columns={'index':'피처'})                 # 'index' 컬럼명을 '피처'로 변경

    summary['결측값 개수'] = df.isnull().sum().values                 # 각 피처의 결측값(null) 개수 계산
    summary['고유값 개수'] = df.nunique().values                      # 각 피처의 고유값 개수 계산

    for i in range(n):
        summary[f"{i+1}번째 값"] = df.iloc[i].values

    return summary                                                     # 요약 테이블 반환

# %%
# 2. pandas로 데이터 불러오기
import pandas as pd

# ▶ Feature 파일 불러오기
df_features = pd.read_csv('/content/drive/MyDrive/멋쟁이사자처럼_파이널프로젝트/unique_1/train_4.청구입금정보_변동없음.csv')

# %%
# ▶ Segment 파일 불러오기 (ID + Segment)
df_segment = pd.read_csv('/content/drive/MyDrive/멋쟁이사자처럼_파이널프로젝트/unique_1/Segment_병합.csv')

# ▶ Segment만 순서대로 붙이기 (ID 순서 동일하다는 전제)
df_features['Segment'] = df_segment['Segment'].values

# ▶ 확인
display(resumetable(df_features,3))
# df_features[['ID', 'Segment']]
# Out:
# 데이터셋 크기: (2400000, 45)
#                   피처  데이터 타입  결측값 개수  고유값 개수         1번째 값         2번째 값  \
# 0               기준년월   int64       0       6        201807        201807
# 1                 ID  object       0  400000  TRAIN_000000  TRAIN_000001
# 2              대표결제일   int64       0      11            27            13
# 3      대표청구지고객주소구분코드  object       0       3           미확인           주거지
# 4       대표청구서수령지구분코드  object       0       7     당사페이앱+이메일            우편
# 5            청구서수령방법  object       0       6         문자메세지            우편
# 6         청구서발송여부_B0   int64       0       2             1             1
# 7        청구서발송여부_R3M   int64       0       2             1             1
# 8        청구서발송여부_R6M   int64       0       2             1             1
# 9            청구금액_B0   int64       0   52973         12226          5834
# 10          청구금액_R3M   int64       0  121539         46588         10530
# 11          청구금액_R6M   int64       0  205357         88693         16861
# 12   포인트_마일리지_건별_B0M   int64       0    1649             0             0
# 13   포인트_마일리지_건별_R3M   int64       0    5129             0             0
# 14    포인트_포인트_건별_B0M   int64       0    5514          1444             0
# 15    포인트_포인트_건별_R3M   int64       0   16009          1827             0
# 16  포인트_마일리지_월적립_B0M   int64       0     793             0             0
# 17  포인트_마일리지_월적립_R3M   int64       0    2249             0             0
# 18   포인트_포인트_월적립_B0M   int64       0    3102             0             0
# 19   포인트_포인트_월적립_R3M   int64       0   24776             0             0
# 20    포인트_적립포인트_R12M   int64       0   72114          3460             0
# 21     포인트_적립포인트_R3M   int64       0   31764          1827             0
# 22    포인트_이용포인트_R12M   int64       0  133159          4008             0
# 23     포인트_이용포인트_R3M   int64       0   52549          1296             0
# 24     포인트_잔여포인트_B0M   int64       0     661             0             0
# 25     마일_적립포인트_R12M   int64       0   25479             0             0
# 26      마일_적립포인트_R3M   int64       0    6673             0             0
# 27     마일_이용포인트_R12M   int64       0   16626             0             0
# 28      마일_이용포인트_R3M   int64       0    4375             0             0
# 29      마일_잔여포인트_B0M   int64       0     734             0             0
# 30          할인건수_R3M  object       0       5         1회 이상         1회 이상
# 31          할인금액_R3M   int64       0    1258             0             0
# 32          할인금액_B0M   int64       0     392             0             0
# 33      할인금액_청구서_R3M   int64       0    1723             0           304
# 34      할인금액_청구서_B0M   int64       0     584             0           163
# 35     상환개월수_결제일_R6M   int64       0       7             5             6
# 36     상환개월수_결제일_R3M   int64       0       4             3             3
# 37         선결제건수_R6M   int64       0       9             0             0
# 38         선결제건수_R3M   int64       0       5             0             0
# 39          연체건수_R6M   int64       0       9             1             0
# 40          연체건수_R3M   int64       0       5             0             0
# 41        혜택수혜금액_R3M   int64       0    1688             3             0
# 42   포인트_마일리지_환산_B0M   int64       0     476             0             0
# 43            혜택수혜금액   int64       0     412             0             0
# 44           Segment  object       0       5             D             E
#
#            3번째 값
# 0         201807
# 1   TRAIN_000002
# 2              1
# 3            미확인
# 4            이메일
# 5            이메일
# 6              1
# 7              1
# 8              1
# 9          21866
# 10         85931
# 11        165221
# 12             0
# 13             0
# 14          2305
# 15          5153
# 16             0
# 17             0
# 18             0
# 19             0
# 20         17135
# 21          5153
# 22          8312
# 23          2765
# 24             0
# 25             0
# 26             0
# 27             0
# 28             0
# 29             0
# 30         1회 이상
# 31             0
# 32             0
# 33             0
# 34             0
# 35             6
# 36             3
# 37             0
# 38             0
# 39             0
# 40             0
# 41           121
# 42             0
# 43            50
# 44             C

# %%
from sklearn.preprocessing import LabelEncoder

# 1. Segment를 숫자로 변환
le = LabelEncoder()
df_features['Segment_encoded'] = le.fit_transform(df_features['Segment'])

# 2. 숫자형 컬럼만 선택
numeric_cols = df_features.select_dtypes(include=['number']).columns.drop('Segment_encoded', errors='ignore')

# 3. 상관계수 계산
correlations = df_features[numeric_cols].corrwith(df_features['Segment_encoded'])

# ✅ 절댓값 적용 여부 → 아래 한 줄 주석처리로 토글
correlations = correlations.abs()

# 4. 정렬
correlations_sorted = correlations.sort_values(ascending=False)

# 5. 출력 형식
pd.set_option('display.float_format', lambda x: f'{x:.6f}')
pd.set_option('display.max_rows', None)

# 6. 출력
display(correlations_sorted)
# Out:
# 청구금액_R6M           0.597904
# 청구금액_R3M           0.590678
# 청구금액_B0            0.577988
# 혜택수혜금액_R3M         0.355754
# 혜택수혜금액             0.350857
# 포인트_마일리지_환산_B0M    0.281306
# 마일_적립포인트_R3M       0.276183
# 포인트_마일리지_건별_R3M    0.216643
# 포인트_마일리지_건별_B0M    0.214917
# 마일_적립포인트_R12M      0.213707
# 마일_이용포인트_R3M       0.213142
# 마일_이용포인트_R12M      0.212008
# 청구서발송여부_B0         0.209534
# 할인금액_청구서_R3M       0.202703
# 할인금액_청구서_B0M       0.196683
# 청구서발송여부_R3M        0.187036
# 할인금액_R3M           0.185652
# 마일_잔여포인트_B0M       0.183546
# 포인트_마일리지_월적립_R3M   0.180634
# 할인금액_B0M           0.180181
# 포인트_마일리지_월적립_B0M   0.175594
# 포인트_적립포인트_R12M     0.175362
# 포인트_적립포인트_R3M      0.173286
# 포인트_이용포인트_R3M      0.170152
# 선결제건수_R6M          0.158875
# 청구서발송여부_R6M        0.153697
# 상환개월수_결제일_R6M      0.149048
# 선결제건수_R3M          0.147391
# 포인트_포인트_건별_R3M     0.146727
# 포인트_포인트_건별_B0M     0.144547
# 포인트_이용포인트_R12M     0.143241
# 상환개월수_결제일_R3M      0.133415
# 포인트_포인트_월적립_R3M    0.125670
# 포인트_포인트_월적립_B0M    0.115605
# 연체건수_R6M           0.060504
# 연체건수_R3M           0.054814
# 대표결제일              0.003646
# 포인트_잔여포인트_B0M      0.002584
# 기준년월               0.000000
# dtype: float64

# %%
# 7. 상관계수 0.35 이상 컬럼만 선택
selected_cols = correlations_sorted[correlations_sorted >= 0.35].index.tolist()

# 8. 해당 컬럼만 추출
X_selected = df_features[selected_cols]

# 9. 확인
print("선택된 컬럼 수:", len(selected_cols))
display(X_selected.head(10))
# Out:
# 선택된 컬럼 수: 5
#    청구금액_R6M  청구금액_R3M  청구금액_B0  혜택수혜금액_R3M  혜택수혜금액
# 0     88693     46588    12226           3       0
# 1     16861     10530     5834           0       0
# 2    165221     85931    21866         121      50
# 3    127371     61518    16356           3       2
# 4       155         0        0           0       0
# 5         0         0        0           0       0
# 6     33966     16464     5512           0       0
# 7     10610      5308     1600           2       1
# 8     94241     62715    20512         540     273
# 9         0         0        0           0       0

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

def calculate_vif(df):
    X_const = add_constant(df)  # 상수항 추가
    vif_data = pd.DataFrame()
    vif_data["feature"] = df.columns
    vif_data["VIF"] = [
        variance_inflation_factor(X_const.values, i + 1)  # +1: 상수항 제외
        for i in range(df.shape[1])
    ]
    return vif_data.sort_values(by="VIF", ascending=False)

# %%
# 결측치 제거가 완료되었으므로 바로 계산
vif_result = calculate_vif(X_selected)

# 결과 확인
display(vif_result)
# Out:
#       feature       VIF
# 1    청구금액_R3M 19.684930
# 3  혜택수혜금액_R3M 11.969779
# 4      혜택수혜금액 11.847078
# 2     청구금액_B0 11.366719
# 0    청구금액_R6M  8.967088

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
import warnings

warnings.filterwarnings('ignore')

# 교차검증 함수 수정
def evaluate_cv_score(X_input, y_input, cv=5):
    model = XGBClassifier(
        random_state=42,
        n_jobs=-1,
        use_label_encoder=False,
        eval_metric='mlogloss',
        tree_method='gpu_hist'  # GPU 사용 설정
    )
    scores = cross_val_score(model, X_input, y_input, cv=cv, scoring='f1_micro')
    return scores.mean()

# ▶ 초기 설정
X_vif = X_selected.copy()
y_vif = df_features.loc[X_vif.index, 'Segment_encoded']
iteration = 0

while True:
    # 1. 상수항 추가 후 VIF 계산
    X_const = sm.add_constant(X_vif)
    vif = pd.DataFrame()
    vif['변수'] = X_const.columns
    vif['VIF'] = [variance_inflation_factor(X_const.values, i) for i in range(X_const.shape[1])]
    vif = vif.sort_values(by='VIF', ascending=False)

    # 2. const는 제외하고 가장 VIF 높은 컬럼 찾기
    vif_no_const = vif[vif['변수'] != 'const']
    top_vif = vif_no_const.iloc[0]

    print(f"[{iteration}] 🔍 최상위 VIF 컬럼: {top_vif['변수']} (VIF={top_vif['VIF']:.2f})")

    # 3. 모두 기준 이하라면 종료
    if top_vif['VIF'] <= 10:
        print(f"✅ 모든 컬럼의 VIF가 10 이하입니다. 종료합니다.")
        break

    # 4. 성능 측정
    f1 = evaluate_cv_score(X_vif, y_vif)
    print(f"   현재 컬럼 수: {X_vif.shape[1]}, F1 Score: {f1:.4f}")

    # 5. 컬럼 제거
    print(f"   🗑️ '{top_vif['변수']}' 제거\n")
    X_vif = X_vif.drop(columns=[top_vif['변수']])
    iteration += 1
# Out:
# [0] 🔍 최상위 VIF 컬럼: 청구금액_R3M (VIF=19.68)
#    현재 컬럼 수: 5, F1 Score: 0.8355
#    🗑️ '청구금액_R3M' 제거
#
# [1] 🔍 최상위 VIF 컬럼: 혜택수혜금액_R3M (VIF=11.92)
#    현재 컬럼 수: 4, F1 Score: 0.8355
#    🗑️ '혜택수혜금액_R3M' 제거
#
# [2] 🔍 최상위 VIF 컬럼: 청구금액_B0 (VIF=5.30)
# ✅ 모든 컬럼의 VIF가 10 이하입니다. 종료합니다.

# %%
# 루프 종료 후 최종 컬럼 확인
print("✅ 최종 남은 컬럼 수:", len(X_vif.columns))
print("✅ 최종 남은 컬럼 목록:")
print(X_vif.columns.tolist())
# Out:
# ✅ 최종 남은 컬럼 수: 3
# ✅ 최종 남은 컬럼 목록:
# ['청구금액_R6M', '청구금액_B0', '혜택수혜금액']
