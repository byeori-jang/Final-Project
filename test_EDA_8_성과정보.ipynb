# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import gc

# 그래프 설정
sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 13
plt.rcParams['axes.unicode_minus'] = False

# %%
# 데이터프레임을 넣고 column별 특성 및 결측값, 고유값들을 확인하는 함수를 작성해본다.
# 필수는 아니지만 전체적인 흐름을 파악하기 쉬워진다.

def resumetable(df, n):
    print(f'데이터셋 크기: {df.shape}')                                # 데이터프레임의 전체 크기(행, 열) 출력

    summary = pd.DataFrame(df.dtypes, columns=['데이터 타입'])         # 각 피처의 데이터 타입을 가져와 데이터프레임으로 생성
    summary = summary.reset_index()                                    # 인덱스를 초기화하여 컬럼으로 변환
    summary = summary.rename(columns={'index':'피처'})                 # 'index' 컬럼명을 '피처'로 변경

    summary['결측값 개수'] = df.isnull().sum().values                 # 각 피처의 결측값(null) 개수 계산
    summary['고유값 개수'] = df.nunique().values                      # 각 피처의 고유값 개수 계산
    
    for i in range(n):
        summary[f"{i+1}번째 값"] = df.iloc[i].values
    
    return summary                                                     # 요약 테이블 반환

# %%
df1 = pd.read_csv('EDA/병합/test_8_성과정보.csv')

# %%
with pd.option_context('display.max_rows', None):
    display(resumetable(df1, 5))
# Out:
# 데이터셋 크기: (600000, 49)
#                     피처   데이터 타입  결측값 개수  고유값 개수       1번째 값       2번째 값  \
# 0                 기준년월    int64       0       6      201807      201807
# 1                   ID   object       0  100000  TEST_00000  TEST_00001
# 2       증감율_이용건수_신용_전월  float64       0  376946    0.204652   -0.340448
# 3       증감율_이용건수_신판_전월  float64       0  376680    0.204652   -0.290936
# 4      증감율_이용건수_일시불_전월  float64       0  376274    0.204652   -0.257185
# 5       증감율_이용건수_할부_전월  float64       0   13518         0.0   -0.583068
# 6       증감율_이용건수_CA_전월  float64       0    3237         0.0   -1.999856
# 7       증감율_이용건수_체크_전월  float64       0   86580         0.0    0.011254
# 8      증감율_이용건수_카드론_전월  float64       0       2         0.0         0.0
# 9       증감율_이용금액_신용_전월  float64       0  446482    1.411951   -0.391841
# 10      증감율_이용금액_신판_전월  float64       0  445880    1.411951   -0.900162
# 11     증감율_이용금액_일시불_전월  float64       0  444362    1.411951   -0.880041
# 12      증감율_이용금액_할부_전월  float64       0   56575         0.0   -0.072539
# 13      증감율_이용금액_CA_전월  float64       0   14178         0.0   -1.999996
# 14      증감율_이용금액_체크_전월  float64       0   77710         0.0   -0.014037
# 15     증감율_이용금액_카드론_전월  float64       0       2         0.0         0.0
# 16      증감율_이용건수_신용_분기  float64       0  419750      1.2052    0.764074
# 17      증감율_이용건수_신판_분기  float64       0  419148      1.2052    0.714821
# 18     증감율_이용건수_일시불_분기  float64       0  417979      1.2052    0.701719
# 19      증감율_이용건수_할부_분기  float64       0   54991         0.0    0.341557
# 20      증감율_이용건수_CA_분기  float64       0    9645         0.0    1.999996
# 21      증감율_이용건수_체크_분기  float64       0   86119         0.0   -0.083033
# 22     증감율_이용건수_카드론_분기  float64       0       3         0.0         0.0
# 23      증감율_이용금액_신용_분기  float64       0  441482    1.211333    0.824935
# 24      증감율_이용금액_신판_분기  float64       0  439028    1.211333    0.620316
# 25     증감율_이용금액_일시불_분기  float64       0  436866    1.211333    0.670012
# 26      증감율_이용금액_할부_분기  float64       0  109792         0.0    0.185371
# 27      증감율_이용금액_CA_분기  float64       0   32957         0.0    0.098998
# 28      증감율_이용금액_체크_분기  float64       0   87238         0.0   -0.079054
# 29     증감율_이용금액_카드론_분기  float64       0       3         0.0         0.0
# 30    잔액_신판평균한도소진율_r6m  float64       0  455191    0.027117    0.154375
# 31    잔액_신판최대한도소진율_r6m  float64       0  485241    0.152151    0.193562
# 32    잔액_신판평균한도소진율_r3m  float64       0  456052    0.068303    0.173801
# 33    잔액_신판최대한도소진율_r3m  float64       0  458726    0.139744    0.183009
# 34  잔액_신판ca평균한도소진율_r6m  float64       0  460573    0.027409    0.237599
# 35  잔액_신판ca최대한도소진율_r6m  float64       0  489470     0.14299    0.329827
# 36  잔액_신판ca평균한도소진율_r3m  float64       0  456121    0.074422    0.282476
# 37  잔액_신판ca최대한도소진율_r3m  float64       0  470188      0.1453    0.324844
# 38           변동률_일시불평잔  float64       0  459276    1.463214    1.315412
# 39         변동률_RV일시불평잔  float64       0   98296    0.999998    0.999998
# 40            변동률_할부평잔  float64       0  217366    0.999998    1.044473
# 41            변동률_CA평잔  float64       0   37494    0.999998    1.991974
# 42          변동률_RVCA평잔  float64       0     654    0.999998    0.999998
# 43           변동률_카드론평잔  float64       0   37094    0.999998    0.926569
# 44          변동률_잔액_B1M  float64       0  429807    0.209395   -0.269161
# 45      변동률_잔액_일시불_B1M  float64       0  400600    0.231043   -0.247241
# 46       변동률_잔액_CA_B1M  float64       0   16871         0.0         0.0
# 47           혜택수혜율_R3M  float64  123715  275193     1.33277         0.0
# 48           혜택수혜율_B0M  float64  140796  240424    1.780392         0.0
#
#          3번째 값       4번째 값       5번째 값
# 0       201807      201807      201807
# 1   TEST_00002  TEST_00003  TEST_00004
# 2    -0.214236    0.011708   -0.136222
# 3    -0.214236    0.011708   -0.136222
# 4    -0.210419    0.011708   -0.052585
# 5    -1.999996         0.0   -1.999996
# 6          0.0         0.0         0.0
# 7          0.0         0.0   -0.379615
# 8          0.0         0.0         0.0
# 9      0.18029    0.286424    -0.93418
# 10     0.18029    0.286424    -0.93418
# 11     0.19507    0.286424   -0.869742
# 12   -1.999996         0.0   -0.121222
# 13         0.0         0.0         0.0
# 14         0.0         0.0   -0.009348
# 15         0.0         0.0         0.0
# 16    0.346043     0.50867    0.124977
# 17    0.346043     0.50867    0.124977
# 18    0.402424    0.465811    0.110963
# 19   -1.109685    1.999996     0.33784
# 20         0.0         0.0         0.0
# 21         0.0         0.0    0.018926
# 22         0.0         0.0         0.0
# 23    0.049106    0.908104    0.420861
# 24    0.049106    0.908104    0.420861
# 25    0.233536    0.622349    0.401456
# 26   -0.330269    1.999996    0.167387
# 27         0.0         0.0         0.0
# 28         0.0         0.0    0.016203
# 29         0.0         0.0         0.0
# 30     0.16502         0.0    0.531094
# 31    0.213651    0.070703    0.759682
# 32    0.194649    0.057699    0.577621
# 33    0.223578    0.111703    0.724324
# 34    0.156283    0.004238    0.511689
# 35    0.203465    0.087512    0.730452
# 36    0.179558    0.074519      0.5759
# 37    0.221608    0.128337    0.737263
# 38    1.055927    1.488069    1.208739
# 39    0.999998    0.999998    0.999998
# 40    1.053083     1.99163    1.053743
# 41    0.999998    0.999998    0.999998
# 42    0.999998    0.999998    0.999998
# 43    0.999998    0.999998    0.999998
# 44    -0.12029    0.035807    -0.53874
# 45     0.02927   -0.013359   -0.449378
# 46         0.0         0.0         0.0
# 47    4.123738    0.093615         0.0
# 48    5.115589    0.349994         0.0

# %%
# train 한쪽 비중 98% 이상인 컬럼 똑같이 제거
df1 = df1.drop(columns = ['증감율_이용건수_카드론_전월', '증감율_이용금액_카드론_전월'])
resumetable(df1,3)
# Out:
# 데이터셋 크기: (600000, 47)
#                     피처   데이터 타입  결측값 개수  고유값 개수       1번째 값       2번째 값  \
# 0                 기준년월    int64       0       6      201807      201807
# 1                   ID   object       0  100000  TEST_00000  TEST_00001
# 2       증감율_이용건수_신용_전월  float64       0  376946    0.204652   -0.340448
# 3       증감율_이용건수_신판_전월  float64       0  376680    0.204652   -0.290936
# 4      증감율_이용건수_일시불_전월  float64       0  376274    0.204652   -0.257185
# 5       증감율_이용건수_할부_전월  float64       0   13518         0.0   -0.583068
# 6       증감율_이용건수_CA_전월  float64       0    3237         0.0   -1.999856
# 7       증감율_이용건수_체크_전월  float64       0   86580         0.0    0.011254
# 8       증감율_이용금액_신용_전월  float64       0  446482    1.411951   -0.391841
# 9       증감율_이용금액_신판_전월  float64       0  445880    1.411951   -0.900162
# 10     증감율_이용금액_일시불_전월  float64       0  444362    1.411951   -0.880041
# 11      증감율_이용금액_할부_전월  float64       0   56575         0.0   -0.072539
# 12      증감율_이용금액_CA_전월  float64       0   14178         0.0   -1.999996
# 13      증감율_이용금액_체크_전월  float64       0   77710         0.0   -0.014037
# 14      증감율_이용건수_신용_분기  float64       0  419750      1.2052    0.764074
# 15      증감율_이용건수_신판_분기  float64       0  419148      1.2052    0.714821
# 16     증감율_이용건수_일시불_분기  float64       0  417979      1.2052    0.701719
# 17      증감율_이용건수_할부_분기  float64       0   54991         0.0    0.341557
# 18      증감율_이용건수_CA_분기  float64       0    9645         0.0    1.999996
# 19      증감율_이용건수_체크_분기  float64       0   86119         0.0   -0.083033
# 20     증감율_이용건수_카드론_분기  float64       0       3         0.0         0.0
# 21      증감율_이용금액_신용_분기  float64       0  441482    1.211333    0.824935
# 22      증감율_이용금액_신판_분기  float64       0  439028    1.211333    0.620316
# 23     증감율_이용금액_일시불_분기  float64       0  436866    1.211333    0.670012
# 24      증감율_이용금액_할부_분기  float64       0  109792         0.0    0.185371
# 25      증감율_이용금액_CA_분기  float64       0   32957         0.0    0.098998
# 26      증감율_이용금액_체크_분기  float64       0   87238         0.0   -0.079054
# 27     증감율_이용금액_카드론_분기  float64       0       3         0.0         0.0
# 28    잔액_신판평균한도소진율_r6m  float64       0  455191    0.027117    0.154375
# 29    잔액_신판최대한도소진율_r6m  float64       0  485241    0.152151    0.193562
# 30    잔액_신판평균한도소진율_r3m  float64       0  456052    0.068303    0.173801
# 31    잔액_신판최대한도소진율_r3m  float64       0  458726    0.139744    0.183009
# 32  잔액_신판ca평균한도소진율_r6m  float64       0  460573    0.027409    0.237599
# 33  잔액_신판ca최대한도소진율_r6m  float64       0  489470     0.14299    0.329827
# 34  잔액_신판ca평균한도소진율_r3m  float64       0  456121    0.074422    0.282476
# 35  잔액_신판ca최대한도소진율_r3m  float64       0  470188      0.1453    0.324844
# 36           변동률_일시불평잔  float64       0  459276    1.463214    1.315412
# 37         변동률_RV일시불평잔  float64       0   98296    0.999998    0.999998
# 38            변동률_할부평잔  float64       0  217366    0.999998    1.044473
# 39            변동률_CA평잔  float64       0   37494    0.999998    1.991974
# 40          변동률_RVCA평잔  float64       0     654    0.999998    0.999998
# 41           변동률_카드론평잔  float64       0   37094    0.999998    0.926569
# 42          변동률_잔액_B1M  float64       0  429807    0.209395   -0.269161
# 43      변동률_잔액_일시불_B1M  float64       0  400600    0.231043   -0.247241
# 44       변동률_잔액_CA_B1M  float64       0   16871         0.0         0.0
# 45           혜택수혜율_R3M  float64  123715  275193     1.33277         0.0
# 46           혜택수혜율_B0M  float64  140796  240424    1.780392         0.0
#
#          3번째 값
# 0       201807
# 1   TEST_00002
# 2    -0.214236
# 3    -0.214236
# 4    -0.210419
# 5    -1.999996
# 6          0.0
# 7          0.0
# 8      0.18029
# 9      0.18029
# 10     0.19507
# 11   -1.999996
# 12         0.0
# 13         0.0
# 14    0.346043
# 15    0.346043
# 16    0.402424
# 17   -1.109685
# 18         0.0
# 19         0.0
# 20         0.0
# 21    0.049106
# 22    0.049106
# 23    0.233536
# 24   -0.330269
# 25         0.0
# 26         0.0
# 27         0.0
# 28     0.16502
# 29    0.213651
# 30    0.194649
# 31    0.223578
# 32    0.156283
# 33    0.203465
# 34    0.179558
# 35    0.221608
# 36    1.055927
# 37    0.999998
# 38    1.053083
# 39    0.999998
# 40    0.999998
# 41    0.999998
# 42    -0.12029
# 43     0.02927
# 44         0.0
# 45    4.123738
# 46    5.115589

# %%
df1.to_csv('EDA/98이상제거/test_8_성과정보_98이상제거_47.csv', index=False, encoding='utf-8-sig')
