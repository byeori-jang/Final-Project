# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import gc

# 그래프 설정
sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 13
plt.rcParams['axes.unicode_minus'] = False

# %%
# 데이터프레임을 넣고 column별 특성 및 결측값, 고유값들을 확인하는 함수를 작성해본다.
# 필수는 아니지만 전체적인 흐름을 파악하기 쉬워진다.

def resumetable(df, n):
    print(f'데이터셋 크기: {df.shape}')                                # 데이터프레임의 전체 크기(행, 열) 출력

    summary = pd.DataFrame(df.dtypes, columns=['데이터 타입'])         # 각 피처의 데이터 타입을 가져와 데이터프레임으로 생성
    summary = summary.reset_index()                                    # 인덱스를 초기화하여 컬럼으로 변환
    summary = summary.rename(columns={'index':'피처'})                 # 'index' 컬럼명을 '피처'로 변경

    summary['결측값 개수'] = df.isnull().sum().values                 # 각 피처의 결측값(null) 개수 계산
    summary['고유값 개수'] = df.nunique().values                      # 각 피처의 고유값 개수 계산

    for i in range(n):
        summary[f"{i+1}번째 값"] = df.iloc[i].values

    return summary                                                     # 요약 테이블 반환

# %%
# 2. pandas로 데이터 불러오기
import pandas as pd

# ▶ Feature 파일 불러오기
df_features = pd.read_csv('/content/drive/MyDrive/멋쟁이사자처럼_파이널프로젝트/unique_1/train_2_신용정보_모델링용.csv')

# %%
# ▶ Segment 파일 불러오기 (ID + Segment)
df_segment = pd.read_csv('/content/drive/MyDrive/멋쟁이사자처럼_파이널프로젝트/unique_1/Segment_병합.csv')

# ▶ Segment만 순서대로 붙이기 (ID 순서 동일하다는 전제)
df_features['Segment'] = df_segment['Segment'].values

# ▶ 확인
display(resumetable(df_features,3))
# df_features[['ID', 'Segment']]
# Out:
# 데이터셋 크기: (2400000, 41)
#                 피처   데이터 타입  결측값 개수   고유값 개수         1번째 값         2번째 값  \
# 0             기준년월    int64       0        6        201807        201807
# 1               ID   object       0   400000  TRAIN_000000  TRAIN_000001
# 2           최초한도금액    int64       0     8802             0             0
# 3         카드이용한도금액    int64       0    81852         19354          9996
# 4           CA한도금액    int64       0    63634          7270          5718
# 5        일시상환론한도금액    int64       0     7307             0         41996
# 6         월상환론한도금액    int64       0    65045             0         90611
# 7        CA이자율_할인전  float64       0  1882014     22.995207     14.793821
# 8        CL이자율_할인전  float64       0  2126771     18.254978     14.834873
# 9     RV일시불이자율_할인전  float64       0  1897473     17.264967     10.622446
# 10  RV현금서비스이자율_할인전  float64       0  2294912     21.234252     13.636594
# 11          RV신청일자    int64       0     2045      99991231      20171009
# 12         RV약정청구율  float64       0    51763           0.0       99.9998
# 13        RV최소결제비율  float64       0        6      19.99996       9.99998
# 14   자발한도감액횟수_R12M   object       0        3            0회            0회
# 15   자발한도감액금액_R12M    int64       0        3             0             0
# 16      자발한도감액후경과월    int64       0        7            12            12
# 17   강제한도감액횟수_R12M    int64       0        5             0             0
# 18   강제한도감액금액_R12M    int64       0        7             0             0
# 19      강제한도감액후경과월    int64       0       13            12            12
# 20     한도증액횟수_R12M   object       0        2            0회            0회
# 21     한도증액금액_R12M    int64       0        4             0             0
# 22        한도증액후경과월    int64       0       13            12            12
# 23        상향가능한도금액    int64       0       18             0             4
# 24      상향가능CA한도금액    int64       0        5             0             1
# 25         카드론동의여부   object       0        2             Y             Y
# 26    월상환론상향가능한도금액    int64       0       14             0             0
# 27        RV전환가능여부   object       0        2             N             Z
# 28   일시불ONLY전환가능여부    int64       0        2             0             1
# 29    카드이용한도금액_B1M    int64       0    91231         20805         10000
# 30    카드이용한도금액_B2M    int64       0    95384         19723          9998
# 31    특별한도보유여부_R3M    int64       0        2             0             0
# 32      연체감액여부_R3M    int64       0        2             0             0
# 33        한도심사요청건수   object       0        2            0회            0회
# 34        한도요청거절건수    int64       0        2             0             0
# 35      한도심사요청후경과월    int64       0        4             3             3
# 36      한도심사거절후경과월    int64       0        4             3             3
# 37    시장단기연체여부_R6M    int64       0        2             0             0
# 38    시장단기연체여부_R3M    int64       0        2             0             0
# 39      rv최초시작후경과일    int64       0     1675      99999999           322
# 40         Segment   object       0        5             D             E
#
#            3번째 값
# 0         201807
# 1   TRAIN_000002
# 2              0
# 3          88193
# 4          35207
# 5              0
# 6              0
# 7      22.014276
# 8      17.875321
# 9      17.155829
# 10     21.226879
# 11      20120117
# 12       99.9998
# 13      19.99996
# 14            0회
# 15             0
# 16            12
# 17             1
# 18             1
# 19             8
# 20            0회
# 21             0
# 22            12
# 23             0
# 24             0
# 25             Y
# 26             0
# 27             N
# 28             0
# 29         78730
# 30         77975
# 31             0
# 32             0
# 33            0회
# 34             0
# 35             3
# 36             3
# 37             0
# 38             0
# 39          2378
# 40             C

# %%
from sklearn.preprocessing import LabelEncoder

# 1. Segment를 숫자로 변환
le = LabelEncoder()
df_features['Segment_encoded'] = le.fit_transform(df_features['Segment'])

# 2. 숫자형 컬럼만 선택
numeric_cols = df_features.select_dtypes(include=['number']).columns.drop('Segment_encoded', errors='ignore')

# 3. 상관계수 계산
correlations = df_features[numeric_cols].corrwith(df_features['Segment_encoded'])

# ✅ 절댓값 적용 여부 → 아래 한 줄 주석처리로 토글
correlations = correlations.abs()

# 4. 정렬
correlations_sorted = correlations.sort_values(ascending=False)

# 5. 출력 형식
pd.set_option('display.float_format', lambda x: f'{x:.6f}')
pd.set_option('display.max_rows', None)

# 6. 출력
display(correlations_sorted)
# Out:
# 카드이용한도금액         0.304435
# 카드이용한도금액_B1M     0.303262
# 카드이용한도금액_B2M     0.303258
# CA한도금액           0.292502
# CA이자율_할인전        0.118189
# 최초한도금액           0.107069
# RV현금서비스이자율_할인전   0.096870
# 일시상환론한도금액        0.094197
# 한도증액금액_R12M      0.084180
# RV일시불이자율_할인전     0.073838
# RV신청일자           0.070184
# rv최초시작후경과일       0.070155
# 상향가능CA한도금액       0.064575
# RV약정청구율          0.054575
# 상향가능한도금액         0.050764
# 월상환론한도금액         0.050272
# 강제한도감액후경과월       0.044601
# 한도증액후경과월         0.039390
# 강제한도감액금액_R12M    0.037438
# CL이자율_할인전        0.037266
# RV최소결제비율         0.031680
# 일시불ONLY전환가능여부    0.019205
# 연체감액여부_R3M       0.013670
# 월상환론상향가능한도금액     0.011388
# 자발한도감액금액_R12M    0.006141
# 강제한도감액횟수_R12M    0.003853
# 특별한도보유여부_R3M     0.002992
# 자발한도감액후경과월       0.002105
# 한도요청거절건수         0.001737
# 한도심사거절후경과월       0.001724
# 시장단기연체여부_R6M     0.001308
# 한도심사요청후경과월       0.001212
# 시장단기연체여부_R3M     0.001072
# 기준년월             0.000000
# dtype: float64
