# %%
import pandas as pd
import gc

# %%
# csv 파일 데이터를 읽어온다.
df1 = pd.read_csv('to_csv_all/to_csv/train/6.채널정보/201807_train_채널정보.csv')
df2 = pd.read_csv('to_csv_all/to_csv/train/6.채널정보/201808_train_채널정보.csv')
df3 = pd.read_csv('to_csv_all/to_csv/train/6.채널정보/201809_train_채널정보.csv')
df4 = pd.read_csv('to_csv_all/to_csv/train/6.채널정보/201810_train_채널정보.csv')
df5 = pd.read_csv('to_csv_all/to_csv/train/6.채널정보/201811_train_채널정보.csv')
df6 = pd.read_csv('to_csv_all/to_csv/train/6.채널정보/201812_train_채널정보.csv')

# %%
# 리스트로 모으기
dfs = [df1, df2, df3, df4, df5, df6]

# 그냥 concat
combined_df = pd.concat(dfs, ignore_index=True)

# CSV로 저장
combined_df.to_csv('train_6.채널정보_병합.csv', index=False, encoding='utf-8-sig')
