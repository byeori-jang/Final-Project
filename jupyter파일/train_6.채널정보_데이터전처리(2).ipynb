# %%
import pandas as pd
import gc

# %%
df_train = pd.read_csv('to_csv_all/to_csv/train/6.채널정보/train_6.채널정보_병합.csv')

# %%
df1 = df_train.drop(columns=['OS구분코드'])

# %%
## 데이터프레임을 넣고 column별 특성 및 결측값, 고유값들을 확인하는 함수를 작성해본다.
## 필수는 아니지만 전체적인 흐름을 파악하기 쉬워진다.

def resumetable(df, n):
    print(f'데이터셋 크기: {df.shape}')                                # 데이터프레임의 전체 크기(행, 열) 출력

    summary = pd.DataFrame(df.dtypes, columns=['데이터 타입'])         # 각 피처의 데이터 타입을 가져와 데이터프레임으로 생성
    summary = summary.reset_index()                                    # 인덱스를 초기화하여 컬럼으로 변환
    summary = summary.rename(columns={'index':'피처'})                 # 'index' 컬럼명을 '피처'로 변경
    summary['결측값 개수'] = df.isnull().sum().values                 # 각 피처의 결측값(null) 개수 계산
    summary['고유값 개수'] = df.nunique().values                      # 각 피처의 고유값 개수 계산
    summary['최솟값'] = df.min(numeric_only=True).reindex(df.columns).values           # 최솟값
    summary['최댓값'] = df.max(numeric_only=True).reindex(df.columns).values           # 최댓값

    for i in range(n):
        summary[f"{i+1}번째 값"] = df.iloc[i].values
    
    return summary                                                     # 요약 테이블 반환

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(resumetable(df1, 1))
# Out:
# 데이터셋 크기: (2400000, 104)
#                     피처  데이터 타입  결측값 개수  고유값 개수       최솟값       최댓값  \
# 0                 기준년월   int64       0       6  201807.0  201812.0
# 1                   ID  object       0  400000       NaN       NaN
# 2         인입횟수_ARS_R6M  object       0       2       NaN       NaN
# 3       이용메뉴건수_ARS_R6M  object       0       4       NaN       NaN
# 4         인입일수_ARS_R6M   int64       0      13       0.0      12.0
# 5         인입월수_ARS_R6M   int64       0       7       0.0       6.0
# 6           인입후경과월_ARS   int64       0       6       0.0       5.0
# 7         인입횟수_ARS_B0M   int64       0       4       0.0       3.0
# 8       이용메뉴건수_ARS_B0M   int64       0       5       0.0       7.0
# 9         인입일수_ARS_B0M   int64       0       3       0.0       2.0
# 10         방문횟수_PC_R6M  object       0       5       NaN       NaN
# 11         방문일수_PC_R6M  object       0       4       NaN       NaN
# 12         방문월수_PC_R6M   int64       0       6       0.0       6.0
# 13       방문후경과월_PC_R6M   int64       0       7       0.0       6.0
# 14          방문횟수_앱_R6M  object       0       9       NaN       NaN
# 15          방문일수_앱_R6M   int64       0      65       0.0      64.0
# 16          방문월수_앱_R6M   int64       0       7       0.0       6.0
# 17        방문후경과월_앱_R6M   int64       0       7       0.0       6.0
# 18       방문횟수_모바일웹_R6M   int64       0      10       0.0      13.0
# 19       방문일수_모바일웹_R6M   int64       0       7       0.0      12.0
# 20       방문월수_모바일웹_R6M   int64       0       2       0.0       1.0
# 21     방문후경과월_모바일웹_R6M   int64       0       7       0.0       6.0
# 22         방문횟수_PC_B0M   int64       0       8       0.0       9.0
# 23         방문일수_PC_B0M   int64       0       6       0.0       6.0
# 24          방문횟수_앱_B0M   int64       0      17       0.0      16.0
# 25          방문일수_앱_B0M   int64       0      12       0.0      11.0
# 26       방문횟수_모바일웹_B0M   int64       0       3       0.0       5.0
# 27       방문일수_모바일웹_B0M   int64       0       2       0.0       4.0
# 28         인입횟수_IB_R6M   int64       0      16       0.0      15.0
# 29      인입횟수_금융_IB_R6M   int64       0       1       0.0       0.0
# 30         인입일수_IB_R6M   int64       0       9       0.0       8.0
# 31         인입월수_IB_R6M   int64       0       7       0.0       6.0
# 32       이용메뉴건수_IB_R6M   int64       0       7       0.0       6.0
# 33       인입후경과월_IB_R6M   int64       0       7       0.0       6.0
# 34         인입횟수_IB_B0M   int64       0       3       0.0       3.0
# 35         인입일수_IB_B0M   int64       0       3       0.0       2.0
# 36       이용메뉴건수_IB_B0M   int64       0       2       0.0       1.0
# 37       인입불만횟수_IB_R6M   int64       0       1       0.0       0.0
# 38       인입불만일수_IB_R6M   int64       0       1       0.0       0.0
# 39       인입불만월수_IB_R6M   int64       0       1       0.0       0.0
# 40     인입불만후경과월_IB_R6M   int64       0       1       6.0       6.0
# 41       인입불만횟수_IB_B0M   int64       0       1       0.0       0.0
# 42       인입불만일수_IB_B0M   int64       0       1       0.0       0.0
# 43            상담건수_B0M   int64       0       3       0.0       3.0
# 44   IB문의건수_사용승인내역_B0M   int64       0       2       0.0       1.0
# 45       IB문의건수_한도_B0M   int64       0       1       0.0       0.0
# 46      IB문의건수_선결제_B0M   int64       0       2       0.0       1.0
# 47       IB문의건수_결제_B0M   int64       0       1       0.0       0.0
# 48       IB문의건수_할부_B0M   int64       0       1       0.0       0.0
# 49     IB문의건수_정보변경_B0M   int64       0       1       0.0       0.0
# 50    IB문의건수_결제일변경_B0M   int64       0       1       0.0       0.0
# 51      IB문의건수_명세서_B0M   int64       0       1       0.0       0.0
# 52     IB문의건수_비밀번호_B0M   int64       0       1       0.0       0.0
# 53      IB문의건수_SMS_B0M   int64       0       1       0.0       0.0
# 54      IB문의건수_APP_B0M   int64       0       1       0.0       0.0
# 55    IB문의건수_부대서비스_B0M   int64       0       1       0.0       0.0
# 56      IB문의건수_포인트_B0M   int64       0       1       0.0       0.0
# 57     IB문의건수_카드발급_B0M   int64       0       2       0.0       1.0
# 58       IB문의건수_BL_B0M   int64       0       1       0.0       0.0
# 59     IB문의건수_분실도난_B0M   int64       0       1       0.0       0.0
# 60       IB문의건수_CA_B0M   int64       0       1       0.0       0.0
# 61    IB문의건수_CL_RV_B0M   int64       0       2       0.0       1.0
# 62       IB문의건수_CS_B0M   int64       0       3       0.0       4.0
# 63      IB상담건수_VOC_B0M   int64       0       1       0.0       0.0
# 64    IB상담건수_VOC민원_B0M   int64       0       1       0.0       0.0
# 65    IB상담건수_VOC불만_B0M   int64       0       1       0.0       0.0
# 66      IB상담건수_금감원_B0M   int64       0       1       0.0       0.0
# 67            상담건수_R6M   int64       0      14       0.0      13.0
# 68   IB문의건수_사용승인내역_R6M   int64       0       3       0.0       2.0
# 69       IB문의건수_한도_R6M   int64       0       2       0.0       2.0
# 70      IB문의건수_선결제_R6M   int64       0       7       0.0       6.0
# 71       IB문의건수_결제_R6M   int64       0       3       0.0       2.0
# 72       IB문의건수_할부_R6M   int64       0       2       0.0       1.0
# 73     IB문의건수_정보변경_R6M   int64       0       2       0.0       1.0
# 74    IB문의건수_결제일변경_R6M   int64       0       4       0.0       5.0
# 75      IB문의건수_명세서_R6M   int64       0       1       0.0       0.0
# 76     IB문의건수_비밀번호_R6M   int64       0       2       0.0       1.0
# 77      IB문의건수_SMS_R6M   int64       0       2       0.0       1.0
# 78      IB문의건수_APP_R6M   int64       0       1       0.0       0.0
# 79    IB문의건수_부대서비스_R6M   int64       0       2       0.0       1.0
# 80      IB문의건수_포인트_R6M   int64       0       3       0.0       4.0
# 81     IB문의건수_카드발급_R6M   int64       0       2       0.0       1.0
# 82       IB문의건수_BL_R6M   int64       0       2       0.0       1.0
# 83     IB문의건수_분실도난_R6M   int64       0       2       0.0       1.0
# 84       IB문의건수_CA_R6M   int64       0       4       0.0       8.0
# 85    IB문의건수_CL_RV_R6M   int64       0       4       0.0       3.0
# 86       IB문의건수_CS_R6M   int64       0       5       0.0       6.0
# 87      IB상담건수_VOC_R6M   int64       0       1       0.0       0.0
# 88    IB상담건수_VOC민원_R6M   int64       0       1       0.0       0.0
# 89    IB상담건수_VOC불만_R6M   int64       0       1       0.0       0.0
# 90      IB상담건수_금감원_R6M   int64       0       1       0.0       0.0
# 91          불만제기건수_B0M   int64       0       1       0.0       0.0
# 92         불만제기건수_R12M   int64       0       1       0.0       0.0
# 93       불만제기후경과월_R12M   int64       0       2       0.0      12.0
# 94      당사PAY_방문횟수_B0M   int64       0       1       0.0       0.0
# 95      당사PAY_방문횟수_R6M   int64       0       1       0.0       0.0
# 96      당사PAY_방문월수_R6M   int64       0       1       0.0       0.0
# 97      당사멤버쉽_방문횟수_B0M   int64       0      26       0.0      63.0
# 98      당사멤버쉽_방문횟수_R6M   int64       0     247       0.0     259.0
# 99      당사멤버쉽_방문월수_R6M   int64       0       7       0.0       6.0
# 100      홈페이지_금융건수_R6M   int64       0      16       0.0      15.0
# 101     홈페이지_선결제건수_R6M   int64       0      31       0.0      30.0
# 102      홈페이지_금융건수_R3M   int64       0       8       0.0       8.0
# 103     홈페이지_선결제건수_R3M   int64       0      17       0.0      16.0
#
#             1번째 값
# 0          201807
# 1    TRAIN_000000
# 2          10회 이상
# 3          10회 이상
# 4               8
# 5               6
# 6               0
# 7               2
# 8               6
# 9               2
# 10          1회 이상
# 11          1회 이상
# 12              0
# 13              6
# 14          1회 이상
# 15              0
# 16              0
# 17              6
# 18              0
# 19              0
# 20              0
# 21              6
# 22              0
# 23              0
# 24              0
# 25              0
# 26              0
# 27              0
# 28              1
# 29              0
# 30              1
# 31              1
# 32              1
# 33              4
# 34              0
# 35              0
# 36              0
# 37              0
# 38              0
# 39              0
# 40              6
# 41              0
# 42              0
# 43              0
# 44              0
# 45              0
# 46              0
# 47              0
# 48              0
# 49              0
# 50              0
# 51              0
# 52              0
# 53              0
# 54              0
# 55              0
# 56              0
# 57              0
# 58              0
# 59              0
# 60              0
# 61              0
# 62              0
# 63              0
# 64              0
# 65              0
# 66              0
# 67              1
# 68              0
# 69              0
# 70              0
# 71              0
# 72              0
# 73              0
# 74              0
# 75              0
# 76              0
# 77              0
# 78              0
# 79              0
# 80              0
# 81              0
# 82              0
# 83              0
# 84              0
# 85              0
# 86              0
# 87              0
# 88              0
# 89              0
# 90              0
# 91              0
# 92              0
# 93             12
# 94              0
# 95              0
# 96              0
# 97             22
# 98            221
# 99              6
# 100             0
# 101             0
# 102             0
# 103             0

# %%
# 결측치 제거된 컬럼 저장
df1.to_csv('train_6.채널정보_병합_결측치제거.csv', index=False, encoding='utf-8-sig')
