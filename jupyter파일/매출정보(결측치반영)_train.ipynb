# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 경고 뜨지 않게 설정
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv('데이터 전처리/to_csv/3.승인매출정보/train/201807_train_승인매출정보(1).csv')
df2 = pd.read_csv('데이터 전처리/to_csv/3.승인매출정보/train/201808_train_승인매출정보(1).csv')
df3 = pd.read_csv('데이터 전처리/to_csv/3.승인매출정보/train/201809_train_승인매출정보(1).csv')
df4 = pd.read_csv('데이터 전처리/to_csv/3.승인매출정보/train/201810_train_승인매출정보(1).csv')
df5 = pd.read_csv('데이터 전처리/to_csv/3.승인매출정보/train/201811_train_승인매출정보(1).csv')
df6 = pd.read_csv('데이터 전처리/to_csv/3.승인매출정보/train/201812_train_승인매출정보(1).csv')

# %%
## 데이터프레임을 넣고 column별 특성 및 결측값, 고유값들을 확인하는 함수를 작성해본다.
## 필수는 아니지만 전체적인 흐름을 파악하기 쉬워진다.

def resumetable(df, n):
    print(f'데이터셋 크기: {df.shape}')                                # 데이터프레임의 전체 크기(행, 열) 출력

    summary = pd.DataFrame(df.dtypes, columns=['데이터 타입'])         # 각 피처의 데이터 타입을 가져와 데이터프레임으로 생성
    summary = summary.reset_index()                                    # 인덱스를 초기화하여 컬럼으로 변환
    summary = summary.rename(columns={'index':'피처'})                 # 'index' 컬럼명을 '피처'로 변경
    summary['결측값 개수'] = df.isnull().sum().values                 # 각 피처의 결측값(null) 개수 계산
    summary['고유값 개수'] = df.nunique().values                      # 각 피처의 고유값 개수 계산
    summary['최솟값'] = df.min(numeric_only=True).reindex(df.columns).values           # 최솟값
    summary['최댓값'] = df.max(numeric_only=True).reindex(df.columns).values           # 최댓값

    for i in range(n):
        summary[f"{i+1}번째 값"] = df.iloc[i].values
    
    return summary                                                     # 요약 테이블 반환

# %%
# 리스트로 모으기
dfs = [df1, df2, df3, df4, df5, df6]

# 그냥 concat
combined_df = pd.concat(dfs, ignore_index=True)

# %%
combined_df['_1순위업종'] = combined_df['_1순위업종'].fillna('미이용')
combined_df['_2순위업종'] = combined_df['_2순위업종'].fillna('미이용')
combined_df['_3순위업종'] = combined_df['_3순위업종'].fillna('미이용')
combined_df['_1순위쇼핑업종'] = combined_df['_1순위쇼핑업종'].fillna('미이용')
combined_df['_2순위쇼핑업종'] = combined_df['_2순위쇼핑업종'].fillna('미이용')
combined_df['_3순위쇼핑업종'] = combined_df['_3순위쇼핑업종'].fillna('미이용')
combined_df['_1순위교통업종'] = combined_df['_1순위교통업종'].fillna('미이용')
combined_df['_2순위교통업종'] = combined_df['_2순위교통업종'].fillna('미이용')
combined_df['_3순위교통업종'] = combined_df['_3순위교통업종'].fillna('미이용')
combined_df['_1순위여유업종'] = combined_df['_1순위여유업종'].fillna('미이용')
combined_df['_2순위여유업종'] = combined_df['_2순위여유업종'].fillna('미이용')
combined_df['_3순위여유업종'] = combined_df['_3순위여유업종'].fillna('미이용')
combined_df['_1순위납부업종'] = combined_df['_1순위납부업종'].fillna('미이용')
combined_df['_2순위납부업종'] = combined_df['_2순위납부업종'].fillna('미이용')
combined_df['_3순위납부업종'] = combined_df['_3순위납부업종'].fillna('미이용')

# %%
combined_df['최종카드론_금융상환방식코드'] = combined_df['최종카드론_금융상환방식코드'].fillna('미이용')
combined_df['최종카드론_신청경로코드'] = combined_df['최종카드론_신청경로코드'].fillna('미이용')
combined_df['최종카드론_대출일자'] = combined_df['최종카드론_대출일자'].fillna('미이용')

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(resumetable(combined_df, 1))
# Out:
# 데이터셋 크기: (2400000, 406)
#                         피처   데이터 타입  결측값 개수  고유값 개수       최솟값           최댓값  \
# 0                     기준년월    int64       0       6  201807.0  2.018120e+05
# 1                       ID   object       0  400000       NaN           NaN
# 2                최종이용일자_기본   object       0    1275       NaN           NaN
# 3                최종이용일자_신판   object       0    1262       NaN           NaN
# 4                최종이용일자_CA   object       0    3097       NaN           NaN
# 5               최종이용일자_카드론   object       0    1667       NaN           NaN
# 6                최종이용일자_체크   object       0    2244       NaN           NaN
# 7               최종이용일자_일시불   object       0    1088       NaN           NaN
# 8                최종이용일자_할부   object       0    2246       NaN           NaN
# 9              이용건수_신용_B0M    int64       0      94      -3.0  9.000000e+01
# 10             이용건수_신판_B0M    int64       0      93      -3.0  8.900000e+01
# 11            이용건수_일시불_B0M    int64       0      92      -3.0  8.800000e+01
# 12             이용건수_할부_B0M    int64       0       4       0.0  3.000000e+00
# 13         이용건수_할부_유이자_B0M    int64       0       2       0.0  1.000000e+00
# 14         이용건수_할부_무이자_B0M    int64       0       3       0.0  2.000000e+00
# 15          이용건수_부분무이자_B0M    int64       0       1       0.0  0.000000e+00
# 16             이용건수_CA_B0M    int64       0       4       0.0  3.000000e+00
# 17             이용건수_체크_B0M    int64       0      72      -1.0  7.000000e+01
# 18            이용건수_카드론_B0M    int64       0       2       0.0  1.000000e+00
# 19            이용금액_일시불_B0M    int64       0   29116   -2663.0  3.042800e+04
# 20             이용금액_할부_B0M    int64       0    8958       0.0  1.362700e+04
# 21         이용금액_할부_유이자_B0M    int64       0    3266       0.0  7.315000e+03
# 22         이용금액_할부_무이자_B0M    int64       0    5009       0.0  8.641000e+03
# 23          이용금액_부분무이자_B0M    int64       0       1       0.0  0.000000e+00
# 24             이용금액_CA_B0M    int64       0   16145       0.0  3.480500e+04
# 25             이용금액_체크_B0M    int64       0   14827   -1380.0  1.619000e+04
# 26            이용금액_카드론_B0M    int64       0     101       0.0  7.347200e+04
# 27               이용후경과월_신용    int64       0      13       0.0  1.200000e+01
# 28               이용후경과월_신판    int64       0      13       0.0  1.200000e+01
# 29              이용후경과월_일시불    int64       0      13       0.0  1.200000e+01
# 30               이용후경과월_할부    int64       0      13       0.0  1.200000e+01
# 31           이용후경과월_할부_유이자    int64       0      12       0.0  1.200000e+01
# 32           이용후경과월_할부_무이자    int64       0      13       0.0  1.200000e+01
# 33            이용후경과월_부분무이자    int64       0      13       0.0  1.200000e+01
# 34               이용후경과월_CA    int64       0      13       0.0  1.200000e+01
# 35               이용후경과월_체크    int64       0      13       0.0  1.200000e+01
# 36              이용후경과월_카드론    int64       0      13       0.0  1.200000e+01
# 37            이용건수_신용_R12M    int64       0    1033      -1.0  1.042000e+03
# 38            이용건수_신판_R12M    int64       0    1029      -1.0  1.034000e+03
# 39           이용건수_일시불_R12M    int64       0    1005      -1.0  1.005000e+03
# 40            이용건수_할부_R12M    int64       0      65       0.0  6.700000e+01
# 41        이용건수_할부_유이자_R12M    int64       0      29       0.0  3.000000e+01
# 42        이용건수_할부_무이자_R12M    int64       0      61       0.0  6.100000e+01
# 43         이용건수_부분무이자_R12M    int64       0       3       0.0  3.000000e+00
# 44            이용건수_CA_R12M    int64       0      31       0.0  3.000000e+01
# 45            이용건수_체크_R12M    int64       0     702      -1.0  7.050000e+02
# 46           이용건수_카드론_R12M    int64       0       4       0.0  3.000000e+00
# 47           이용금액_일시불_R12M    int64       0  259054   -4293.0  8.916700e+05
# 48            이용금액_할부_R12M    int64       0   78728       0.0  2.662520e+05
# 49        이용금액_할부_유이자_R12M    int64       0   36200       0.0  6.187700e+04
# 50        이용금액_할부_무이자_R12M    int64       0   67214       0.0  2.662520e+05
# 51         이용금액_부분무이자_R12M    int64       0    3444       0.0  1.979100e+04
# 52            이용금액_CA_R12M    int64       0  109416       0.0  9.600000e+05
# 53            이용금액_체크_R12M    int64       0   80618    -414.0  8.363700e+04
# 54           이용금액_카드론_R12M    int64       0   14599       0.0  2.924890e+05
# 55         최대이용금액_일시불_R12M    int64       0   83560       0.0  5.464460e+05
# 56          최대이용금액_할부_R12M    int64       0   31796       0.0  3.693200e+04
# 57      최대이용금액_할부_유이자_R12M    int64       0   20182       0.0  2.593500e+04
# 58      최대이용금액_할부_무이자_R12M    int64       0   31792       0.0  3.693200e+04
# 59       최대이용금액_부분무이자_R12M    int64       0    3532       0.0  1.117800e+04
# 60          최대이용금액_CA_R12M    int64       0   44563       0.0  1.598330e+05
# 61          최대이용금액_체크_R12M    int64       0   48671       0.0  1.506530e+05
# 62         최대이용금액_카드론_R12M    int64       0   18857       0.0  1.988520e+05
# 63           이용개월수_신용_R12M    int64       0      13       0.0  1.200000e+01
# 64           이용개월수_신판_R12M    int64       0      13       0.0  1.200000e+01
# 65          이용개월수_일시불_R12M    int64       0      13       0.0  1.200000e+01
# 66           이용개월수_할부_R12M    int64       0      12       0.0  1.100000e+01
# 67       이용개월수_할부_유이자_R12M    int64       0       6       0.0  5.000000e+00
# 68       이용개월수_할부_무이자_R12M    int64       0      11       0.0  1.000000e+01
# 69        이용개월수_부분무이자_R12M    int64       0       2       0.0  1.000000e+00
# 70           이용개월수_CA_R12M    int64       0      13       0.0  1.200000e+01
# 71           이용개월수_체크_R12M    int64       0      12       0.0  1.200000e+01
# 72          이용개월수_카드론_R12M    int64       0       3       0.0  2.000000e+00
# 73             이용건수_신용_R6M    int64       0     564     -18.0  5.480000e+02
# 74             이용건수_신판_R6M    int64       0     564     -18.0  5.480000e+02
# 75            이용건수_일시불_R6M    int64       0     555     -18.0  5.370000e+02
# 76             이용건수_할부_R6M    int64       0      26      -1.0  2.400000e+01
# 77         이용건수_할부_유이자_R6M    int64       0       8      -1.0  6.000000e+00
# 78         이용건수_할부_무이자_R6M    int64       0      22      -1.0  2.000000e+01
# 79          이용건수_부분무이자_R6M    int64       0       2       0.0  1.000000e+00
# 80             이용건수_CA_R6M    int64       0      19       0.0  1.800000e+01
# 81             이용건수_체크_R6M    int64       0     410      -6.0  4.090000e+02
# 82            이용건수_카드론_R6M    int64       0       3       0.0  2.000000e+00
# 83            이용금액_일시불_R6M    int64       0  145107  -19798.0  1.761700e+05
# 84             이용금액_할부_R6M    int64       0   55814   -9455.0  8.051000e+04
# 85         이용금액_할부_유이자_R6M    int64       0   34498  -12572.0  3.812800e+04
# 86         이용금액_할부_무이자_R6M    int64       0   45206   -9455.0  4.976800e+04
# 87          이용금액_부분무이자_R6M    int64       0    4414    -679.0  1.300000e+04
# 88             이용금액_CA_R6M    int64       0   79010       0.0  4.900000e+05
# 89             이용금액_체크_R6M    int64       0   73561   -4220.0  9.220100e+04
# 90            이용금액_카드론_R6M    int64       0   29862       0.0  1.404570e+05
# 91            이용개월수_신용_R6M    int64       0       7       0.0  6.000000e+00
# 92            이용개월수_신판_R6M    int64       0       7       0.0  6.000000e+00
# 93           이용개월수_일시불_R6M    int64       0       7       0.0  6.000000e+00
# 94            이용개월수_할부_R6M    int64       0       7       0.0  6.000000e+00
# 95        이용개월수_할부_유이자_R6M    int64       0       7       0.0  6.000000e+00
# 96        이용개월수_할부_무이자_R6M    int64       0       7       0.0  6.000000e+00
# 97         이용개월수_부분무이자_R6M    int64       0       2       0.0  1.000000e+00
# 98            이용개월수_CA_R6M    int64       0       7       0.0  6.000000e+00
# 99            이용개월수_체크_R6M    int64       0       7       0.0  6.000000e+00
# 100          이용개월수_카드론_R6M    int64       0       3       0.0  2.000000e+00
# 101            이용건수_신용_R3M    int64       0     297      -9.0  2.880000e+02
# 102            이용건수_신판_R3M    int64       0     297      -9.0  2.880000e+02
# 103           이용건수_일시불_R3M    int64       0     293      -9.0  2.840000e+02
# 104            이용건수_할부_R3M    int64       0      12      -1.0  1.000000e+01
# 105        이용건수_할부_유이자_R3M    int64       0       5      -1.0  3.000000e+00
# 106        이용건수_할부_무이자_R3M    int64       0       8      -1.0  6.000000e+00
# 107         이용건수_부분무이자_R3M    int64       0       2       0.0  1.000000e+00
# 108            이용건수_CA_R3M    int64       0      10       0.0  9.000000e+00
# 109            이용건수_체크_R3M    int64       0     211      -3.0  2.070000e+02
# 110           이용건수_카드론_R3M    int64       0       2       0.0  1.000000e+00
# 111           이용금액_일시불_R3M    int64       0   80856  -14492.0  8.930300e+04
# 112            이용금액_할부_R3M    int64       0   30432   -1642.0  4.031800e+04
# 113        이용금액_할부_유이자_R3M    int64       0   16683   -5405.0  1.961600e+04
# 114        이용금액_할부_무이자_R3M    int64       0   21279   -2116.0  2.679500e+04
# 115         이용금액_부분무이자_R3M    int64       0    2573    -679.0  2.694000e+03
# 116            이용금액_CA_R3M    int64       0   49467       0.0  1.803170e+05
# 117            이용금액_체크_R3M    int64       0   41749   -2888.0  4.723400e+04
# 118           이용금액_카드론_R3M    int64       0    7328       0.0  9.986400e+04
# 119           이용개월수_신용_R3M    int64       0       4       0.0  3.000000e+00
# 120           이용개월수_신판_R3M    int64       0       4       0.0  3.000000e+00
# 121          이용개월수_일시불_R3M    int64       0       4       0.0  3.000000e+00
# 122           이용개월수_할부_R3M    int64       0       4       0.0  3.000000e+00
# 123       이용개월수_할부_유이자_R3M    int64       0       4       0.0  3.000000e+00
# 124       이용개월수_할부_무이자_R3M    int64       0       4       0.0  3.000000e+00
# 125        이용개월수_부분무이자_R3M    int64       0       2       0.0  1.000000e+00
# 126           이용개월수_CA_R3M    int64       0       4       0.0  3.000000e+00
# 127           이용개월수_체크_R3M    int64       0       4       0.0  3.000000e+00
# 128          이용개월수_카드론_R3M    int64       0       2       0.0  1.000000e+00
# 129                 이용가맹점수    int64       0     109       0.0  1.080000e+02
# 130                이용금액_해외    int64       0    4292       0.0  1.001100e+04
# 131            쇼핑_도소매_이용금액    int64       0    6299       0.0  1.149300e+04
# 132            쇼핑_백화점_이용금액    int64       0    1508       0.0  2.735000e+03
# 133             쇼핑_마트_이용금액    int64       0    4128       0.0  7.088000e+03
# 134           쇼핑_슈퍼마켓_이용금액    int64       0    4000       0.0  6.984000e+03
# 135            쇼핑_편의점_이용금액    int64       0    4273       0.0  8.070000e+03
# 136            쇼핑_아울렛_이용금액    int64       0     720       0.0  1.347000e+03
# 137            쇼핑_온라인_이용금액    int64       0   35442       0.0  1.360750e+05
# 138             쇼핑_기타_이용금액    int64       0     799       0.0  1.157000e+03
# 139              교통_주유이용금액    int64       0    7527       0.0  1.449000e+04
# 140              교통_정비이용금액    int64       0    1328       0.0  2.193000e+03
# 141             교통_통행료이용금액    int64       0      45       0.0  3.670000e+02
# 142           교통_버스지하철이용금액    int64       0    2070       0.0  2.166000e+03
# 143              교통_택시이용금액    int64       0     733       0.0  1.087000e+03
# 144            교통_철도버스이용금액    int64       0     631       0.0  1.088000e+03
# 145              여유_운동이용금액    int64       0    1999       0.0  3.507000e+03
# 146             여유_Pet이용금액    int64       0     360       0.0  8.330000e+02
# 147              여유_공연이용금액    int64       0     183       0.0  3.540000e+02
# 148              여유_공원이용금액    int64       0     134       0.0  3.580000e+02
# 149              여유_숙박이용금액    int64       0     517       0.0  1.135000e+03
# 150              여유_여행이용금액    int64       0       1       0.0  0.000000e+00
# 151              여유_항공이용금액    int64       0    1252       0.0  5.213000e+03
# 152              여유_기타이용금액    int64       0     249       0.0  4.270000e+02
# 153             납부_통신비이용금액    int64       0    6062       0.0  9.305000e+03
# 154             납부_관리비이용금액    int64       0    1064       0.0  5.519000e+03
# 155             납부_렌탈료이용금액    int64       0       1       0.0  0.000000e+00
# 156           납부_가스전기료이용금액    int64       0     461       0.0  9.840000e+02
# 157             납부_보험료이용금액    int64       0    2603       0.0  5.493000e+03
# 158            납부_유선방송이용금액    int64       0       1       0.0  0.000000e+00
# 159            납부_건강연금이용금액    int64       0       1       0.0  0.000000e+00
# 160              납부_기타이용금액    int64       0    1120       0.0  1.785000e+03
# 161                 _1순위업종   object       0      11       NaN           NaN
# 162            _1순위업종_이용금액    int64       0   59635       0.0  1.901870e+05
# 163                 _2순위업종   object       0      11       NaN           NaN
# 164            _2순위업종_이용금액    int64       0   22337       0.0  4.934500e+04
# 165                 _3순위업종   object       0      11       NaN           NaN
# 166            _3순위업종_이용금액    int64       0   13139       0.0  2.254600e+04
# 167               _1순위쇼핑업종   object       0       9       NaN           NaN
# 168          _1순위쇼핑업종_이용금액    int64       0   35442       0.0  1.360750e+05
# 169               _2순위쇼핑업종   object       0       9       NaN           NaN
# 170          _2순위쇼핑업종_이용금액    int64       0    5629       0.0  1.049400e+04
# 171               _3순위쇼핑업종   object       0       9       NaN           NaN
# 172          _3순위쇼핑업종_이용금액    int64       0    3949       0.0  7.088000e+03
# 173               _1순위교통업종   object       0       6       NaN           NaN
# 174          _1순위교통업종_이용금액    int64       0    8222       0.0  1.449000e+04
# 175               _2순위교통업종   object       0       7       NaN           NaN
# 176          _2순위교통업종_이용금액    int64       0    1901       0.0  2.193000e+03
# 177               _3순위교통업종   object       0       6       NaN           NaN
# 178          _3순위교통업종_이용금액    int64       0    1023       0.0  1.247000e+03
# 179               _1순위여유업종   object       0       8       NaN           NaN
# 180          _1순위여유업종_이용금액    int64       0    3352       0.0  5.213000e+03
# 181               _2순위여유업종   object       0       8       NaN           NaN
# 182          _2순위여유업종_이용금액    int64       0    1637       0.0  3.135000e+03
# 183               _3순위여유업종   object       0       7       NaN           NaN
# 184          _3순위여유업종_이용금액    int64       0     652       0.0  9.620000e+02
# 185               _1순위납부업종   object       0       6       NaN           NaN
# 186          _1순위납부업종_이용금액    int64       0    6563       0.0  9.305000e+03
# 187               _2순위납부업종   object       0       6       NaN           NaN
# 188          _2순위납부업종_이용금액    int64       0    4845       0.0  5.234000e+03
# 189               _3순위납부업종   object       0       5       NaN           NaN
# 190          _3순위납부업종_이용금액    int64       0    2787       0.0  3.449000e+03
# 191           할부건수_3M_R12M    int64       0      52       0.0  5.200000e+01
# 192           할부건수_6M_R12M    int64       0      21       0.0  2.100000e+01
# 193          할부건수_12M_R12M    int64       0       8       0.0  1.000000e+01
# 194          할부건수_14M_R12M    int64       0       4       0.0  4.000000e+00
# 195           할부금액_3M_R12M    int64       0   59959       0.0  2.662520e+05
# 196           할부금액_6M_R12M    int64       0   31996       0.0  7.370600e+04
# 197          할부금액_12M_R12M    int64       0   16732       0.0  2.736600e+04
# 198          할부금액_14M_R12M    int64       0    2824       0.0  5.108600e+04
# 199       할부건수_유이자_3M_R12M    int64       0      18       0.0  1.800000e+01
# 200       할부건수_유이자_6M_R12M    int64       0       5       0.0  6.000000e+00
# 201      할부건수_유이자_12M_R12M    int64       0       4       0.0  5.000000e+00
# 202      할부건수_유이자_14M_R12M    int64       0       3       0.0  4.000000e+00
# 203       할부금액_유이자_3M_R12M    int64       0   20726       0.0  2.788100e+04
# 204       할부금액_유이자_6M_R12M    int64       0    7950       0.0  1.695600e+04
# 205      할부금액_유이자_12M_R12M    int64       0    6170       0.0  1.929100e+04
# 206      할부금액_유이자_14M_R12M    int64       0    2001       0.0  6.136000e+03
# 207       할부건수_무이자_3M_R12M    int64       0      49       0.0  4.900000e+01
# 208       할부건수_무이자_6M_R12M    int64       0      16       0.0  1.600000e+01
# 209      할부건수_무이자_12M_R12M    int64       0       3       0.0  4.000000e+00
# 210      할부건수_무이자_14M_R12M    int64       0       2       0.0  2.000000e+00
# 211       할부금액_무이자_3M_R12M    int64       0   53983       0.0  2.662520e+05
# 212       할부금액_무이자_6M_R12M    int64       0   29021       0.0  7.370600e+04
# 213      할부금액_무이자_12M_R12M    int64       0    2331       0.0  5.609000e+03
# 214      할부금액_무이자_14M_R12M    int64       0     735       0.0  5.108600e+04
# 215        할부건수_부분_3M_R12M    int64       0       1       0.0  0.000000e+00
# 216        할부건수_부분_6M_R12M    int64       0       1       0.0  0.000000e+00
# 217       할부건수_부분_12M_R12M    int64       0       3       0.0  3.000000e+00
# 218       할부건수_부분_14M_R12M    int64       0       1       0.0  0.000000e+00
# 219        할부금액_부분_3M_R12M    int64       0       1       0.0  0.000000e+00
# 220        할부금액_부분_6M_R12M    int64       0       2       0.0  4.249000e+03
# 221       할부금액_부분_12M_R12M    int64       0    3364       0.0  1.232900e+04
# 222       할부금액_부분_14M_R12M    int64       0      79       0.0  1.118200e+04
# 223               RP건수_B0M    int64       0       9       0.0  8.000000e+00
# 224               RP금액_B0M    int64       0   11445       0.0  2.856600e+04
# 225             RP유형건수_B0M    int64       0       5       0.0  4.000000e+00
# 226            RP건수_통신_B0M    int64       0       4       0.0  3.000000e+00
# 227           RP건수_아파트_B0M    int64       0       2       0.0  1.000000e+00
# 228    RP건수_제휴사서비스직접판매_B0M    int64       0       2       0.0  1.000000e+00
# 229            RP건수_렌탈_B0M    int64       0       4       0.0  3.000000e+00
# 230            RP건수_가스_B0M    int64       0       2       0.0  1.000000e+00
# 231            RP건수_전기_B0M    int64       0       2       0.0  1.000000e+00
# 232            RP건수_보험_B0M    int64       0       2       0.0  1.000000e+00
# 233           RP건수_학습비_B0M    int64       0       4       0.0  3.000000e+00
# 234          RP건수_유선방송_B0M    int64       0       1       0.0  0.000000e+00
# 235            RP건수_건강_B0M    int64       0       1       0.0  0.000000e+00
# 236            RP건수_교통_B0M    int64       0       4       0.0  3.000000e+00
# 237                 RP후경과월    int64       0       7       0.0  6.000000e+00
# 238              RP후경과월_통신    int64       0       7       0.0  6.000000e+00
# 239             RP후경과월_아파트    int64       0       7       0.0  6.000000e+00
# 240      RP후경과월_제휴사서비스직접판매    int64       0       7       0.0  6.000000e+00
# 241              RP후경과월_렌탈    int64       0       7       0.0  6.000000e+00
# 242              RP후경과월_가스    int64       0       7       0.0  6.000000e+00
# 243              RP후경과월_전기    int64       0       7       0.0  6.000000e+00
# 244              RP후경과월_보험    int64       0       7       0.0  6.000000e+00
# 245             RP후경과월_학습비    int64       0       7       0.0  6.000000e+00
# 246            RP후경과월_유선방송    int64       0       1       6.0  6.000000e+00
# 247              RP후경과월_건강    int64       0       1       6.0  6.000000e+00
# 248              RP후경과월_교통    int64       0       7       0.0  6.000000e+00
# 249             증감_RP건수_전월    int64       0       9      -4.0  4.000000e+00
# 250           증감_RP유형건수_전월    int64       0       3      -1.0  1.000000e+00
# 251          증감_RP건수_통신_전월    int64       0       5      -2.0  2.000000e+00
# 252         증감_RP건수_아파트_전월    int64       0       3      -1.0  1.000000e+00
# 253  증감_RP건수_제휴사서비스직접판매_전월    int64       0       3      -1.0  1.000000e+00
# 254          증감_RP건수_렌탈_전월    int64       0       7      -3.0  3.000000e+00
# 255          증감_RP건수_가스_전월    int64       0       3      -1.0  1.000000e+00
# 256          증감_RP건수_전기_전월    int64       0       3      -1.0  1.000000e+00
# 257          증감_RP건수_보험_전월    int64       0       3      -1.0  1.000000e+00
# 258         증감_RP건수_학습비_전월    int64       0       7      -3.0  3.000000e+00
# 259        증감_RP건수_유선방송_전월    int64       0       1       0.0  0.000000e+00
# 260          증감_RP건수_건강_전월    int64       0       1       0.0  0.000000e+00
# 261          증감_RP건수_교통_전월    int64       0       6      -2.0  3.000000e+00
# 262             최초카드론이용경과월    int64       0     442       3.0  9.990000e+02
# 263             최종카드론이용경과월    int64       0      68       0.0  9.990000e+02
# 264             카드론이용건수_누적    int64       0      18       0.0  1.700000e+01
# 265             카드론이용월수_누적    int64       0      15       0.0  1.400000e+01
# 266             카드론이용금액_누적    int64       0   61096       0.0  1.903389e+06
# 267         최종카드론_금융상환방식코드   object       0       4       NaN           NaN
# 268           최종카드론_신청경로코드   object       0       6       NaN           NaN
# 269             최종카드론_대출이율  float64       0  440724       0.0  2.042148e+01
# 270             최종카드론_대출일자   object       0    1667       NaN           NaN
# 271             최종카드론_대출월수    int64       0       7       0.0  3.600000e+01
# 272            최종카드론_거치개월수    int64       0       4       0.0  6.000000e+00
# 273             최종카드론_대출금액    int64       0  117127       0.0  1.849800e+05
# 274          이용개월수_온라인_R6M    int64       0       7       0.0  6.000000e+00
# 275         이용개월수_오프라인_R6M    int64       0       7       0.0  6.000000e+00
# 276           이용금액_온라인_R6M    int64       0   57787       0.0  2.947840e+05
# 277          이용금액_오프라인_R6M    int64       0  155201       0.0  6.229340e+05
# 278           이용건수_온라인_R6M    int64       0     174       0.0  1.890000e+02
# 279          이용건수_오프라인_R6M    int64       0    1054       0.0  1.101000e+03
# 280           이용금액_온라인_R3M    int64       0   29566       0.0  1.387850e+05
# 281          이용금액_오프라인_R3M    int64       0   79022       0.0  3.300760e+05
# 282           이용건수_온라인_R3M    int64       0      82       0.0  8.500000e+01
# 283          이용건수_오프라인_R3M    int64       0     526       0.0  5.700000e+02
# 284           이용금액_온라인_B0M    int64       0    9464       0.0  1.897700e+04
# 285          이용금액_오프라인_B0M    int64       0   16595       0.0  5.138800e+04
# 286           이용건수_온라인_B0M    int64       0      17       0.0  1.900000e+01
# 287          이용건수_오프라인_B0M    int64       0      76       0.0  7.500000e+01
# 288       이용개월수_페이_온라인_R6M    int64       0       7       0.0  6.000000e+00
# 289      이용개월수_페이_오프라인_R6M    int64       0       7       0.0  6.000000e+00
# 290        이용금액_페이_온라인_R6M    int64       0   51549       0.0  1.916600e+05
# 291       이용금액_페이_오프라인_R6M    int64       0   28701       0.0  7.694700e+04
# 292        이용건수_페이_온라인_R6M    int64       0      25       0.0  2.400000e+01
# 293       이용건수_페이_오프라인_R6M    int64       0       9       0.0  1.200000e+01
# 294        이용금액_페이_온라인_R3M    int64       0   25749       0.0  8.363100e+04
# 295       이용금액_페이_오프라인_R3M    int64       0   13099       0.0  3.191600e+04
# 296        이용건수_페이_온라인_R3M    int64       0      14       0.0  1.300000e+01
# 297       이용건수_페이_오프라인_R3M    int64       0       4       0.0  3.000000e+00
# 298        이용금액_페이_온라인_B0M    int64       0    8062       0.0  1.607100e+04
# 299       이용금액_페이_오프라인_B0M    int64       0    3515       0.0  5.269000e+03
# 300        이용건수_페이_온라인_B0M    int64       0       5       0.0  4.000000e+00
# 301       이용건수_페이_오프라인_B0M    int64       0       2       0.0  1.000000e+00
# 302         이용개월수_간편결제_R6M    int64       0       7       0.0  6.000000e+00
# 303         이용개월수_당사페이_R6M    int64       0       1       0.0  0.000000e+00
# 304         이용개월수_당사기타_R6M    int64       0       7       0.0  6.000000e+00
# 305          이용개월수_A페이_R6M    int64       0       7       0.0  6.000000e+00
# 306          이용개월수_B페이_R6M    int64       0       7       0.0  6.000000e+00
# 307          이용개월수_C페이_R6M    int64       0       7       0.0  6.000000e+00
# 308          이용개월수_D페이_R6M    int64       0       7       0.0  6.000000e+00
# 309          이용금액_간편결제_R6M    int64       0   66792       0.0  3.645710e+05
# 310          이용금액_당사페이_R6M    int64       0       1       0.0  0.000000e+00
# 311          이용금액_당사기타_R6M    int64       0       1       0.0  0.000000e+00
# 312           이용금액_A페이_R6M    int64       0   34434       0.0  1.068470e+05
# 313           이용금액_B페이_R6M    int64       0    3446       0.0  4.543000e+03
# 314           이용금액_C페이_R6M    int64       0    2950       0.0  3.935000e+03
# 315           이용금액_D페이_R6M    int64       0    1397       0.0  1.967000e+03
# 316          이용건수_간편결제_R6M    int64       0      31       0.0  3.000000e+01
# 317          이용건수_당사페이_R6M    int64       0       1       0.0  0.000000e+00
# 318          이용건수_당사기타_R6M    int64       0       1       0.0  0.000000e+00
# 319           이용건수_A페이_R6M    int64       0      15       0.0  1.400000e+01
# 320           이용건수_B페이_R6M    int64       0       7       0.0  6.000000e+00
# 321           이용건수_C페이_R6M    int64       0       7       0.0  6.000000e+00
# 322           이용건수_D페이_R6M    int64       0       7       0.0  6.000000e+00
# 323          이용금액_간편결제_R3M    int64       0   35883       0.0  1.403280e+05
# 324          이용금액_당사페이_R3M    int64       0       1       0.0  0.000000e+00
# 325          이용금액_당사기타_R3M    int64       0       1       0.0  0.000000e+00
# 326           이용금액_A페이_R3M    int64       0   16352       0.0  4.133300e+04
# 327           이용금액_B페이_R3M    int64       0    1516       0.0  2.396000e+03
# 328           이용금액_C페이_R3M    int64       0    1593       0.0  2.283000e+03
# 329           이용금액_D페이_R3M    int64       0     724       0.0  1.030000e+03
# 330          이용건수_간편결제_R3M    int64       0      16       0.0  1.500000e+01
# 331          이용건수_당사페이_R3M    int64       0       1       0.0  0.000000e+00
# 332          이용건수_당사기타_R3M    int64       0       1       0.0  0.000000e+00
# 333           이용건수_A페이_R3M    int64       0       8       0.0  7.000000e+00
# 334           이용건수_B페이_R3M    int64       0       4       0.0  3.000000e+00
# 335           이용건수_C페이_R3M    int64       0       4       0.0  3.000000e+00
# 336           이용건수_D페이_R3M    int64       0       4       0.0  3.000000e+00
# 337          이용금액_간편결제_B0M    int64       0   13239       0.0  3.057600e+04
# 338          이용금액_당사페이_B0M    int64       0       1       0.0  0.000000e+00
# 339          이용금액_당사기타_B0M    int64       0       1       0.0  0.000000e+00
# 340           이용금액_A페이_B0M    int64       0    4495       0.0  7.182000e+03
# 341           이용금액_B페이_B0M    int64       0     367       0.0  9.670000e+02
# 342           이용금액_C페이_B0M    int64       0     517       0.0  1.027000e+03
# 343           이용금액_D페이_B0M    int64       0     194       0.0  4.130000e+02
# 344          이용건수_간편결제_B0M    int64       0       6       0.0  5.000000e+00
# 345          이용건수_당사페이_B0M    int64       0       1       0.0  0.000000e+00
# 346          이용건수_당사기타_B0M    int64       0       1       0.0  0.000000e+00
# 347           이용건수_A페이_B0M    int64       0       2       0.0  1.000000e+00
# 348           이용건수_B페이_B0M    int64       0       2       0.0  1.000000e+00
# 349           이용건수_C페이_B0M    int64       0       2       0.0  1.000000e+00
# 350           이용건수_D페이_B0M    int64       0       2       0.0  1.000000e+00
# 351          이용개월수_선결제_R6M    int64       0       7       0.0  6.000000e+00
# 352           이용횟수_선결제_R6M    int64       0      16       0.0  1.500000e+01
# 353           이용금액_선결제_R6M    int64       0   54295       0.0  2.241450e+05
# 354           이용건수_선결제_R6M    int64       0     511       0.0  5.500000e+02
# 355           이용횟수_선결제_R3M    int64       0       9       0.0  8.000000e+00
# 356           이용금액_선결제_R3M    int64       0   25719       0.0  7.530600e+04
# 357           이용건수_선결제_R3M    int64       0     252       0.0  3.390000e+02
# 358           이용횟수_선결제_B0M    int64       0       4       0.0  3.000000e+00
# 359           이용금액_선결제_B0M    int64       0    6173       0.0  1.403400e+04
# 360           이용건수_선결제_B0M    int64       0      48       0.0  1.690000e+02
# 361            이용횟수_연체_R6M    int64       0       7       0.0  6.000000e+00
# 362            이용금액_연체_R6M    int64       0   25731       0.0  7.732800e+04
# 363            이용횟수_연체_R3M    int64       0       4       0.0  3.000000e+00
# 364            이용금액_연체_R3M    int64       0   10597       0.0  2.250200e+04
# 365            이용횟수_연체_B0M    int64       0       2       0.0  1.000000e+00
# 366            이용금액_연체_B0M    int64       0    2583       0.0  4.477000e+03
# 367           이용개월수_전체_R6M    int64       0       7       0.0  6.000000e+00
# 368           이용개월수_전체_R3M    int64       0       4       0.0  3.000000e+00
# 369          이용개월수_결제일_R6M    int64       0       7       0.0  6.000000e+00
# 370          이용개월수_결제일_R3M    int64       0       4       0.0  3.000000e+00
# 371            가맹점매출금액_B1M    int64       0    4743       0.0  1.248500e+04
# 372            가맹점매출금액_B2M    int64       0    4476       0.0  1.248500e+04
# 373             정상청구원금_B0M    int64       0   38495       0.0  1.233640e+05
# 374              선입금원금_B0M    int64       0   11152       0.0  2.901500e+04
# 375             정상입금원금_B0M    int64       0   36844       0.0  1.233640e+05
# 376             연체입금원금_B0M    int64       0   21486       0.0  3.532400e+04
# 377             정상청구원금_B2M    int64       0   40590       0.0  1.364090e+05
# 378              선입금원금_B2M    int64       0   10941       0.0  2.796300e+04
# 379             정상입금원금_B2M    int64       0   39248       0.0  1.364090e+05
# 380             연체입금원금_B2M    int64       0   22251       0.0  3.557700e+04
# 381             정상청구원금_B5M    int64       0   44539       0.0  1.414550e+05
# 382              선입금원금_B5M    int64       0   10039       0.0  2.608500e+04
# 383             정상입금원금_B5M    int64       0   43485       0.0  1.414550e+05
# 384             연체입금원금_B5M    int64       0   22589       0.0  3.550500e+04
# 385            건수_할부전환_R6M    int64       0       9       0.0  1.100000e+01
# 386            건수_할부전환_R3M    int64       0       5       0.0  6.000000e+00
# 387            금액_할부전환_R6M    int64       0    6411       0.0  1.554200e+04
# 388            금액_할부전환_R3M    int64       0    2473       0.0  8.747000e+03
# 389     연속무실적개월수_기본_24M_카드    int64       0      19       0.0  2.400000e+01
# 390     연속유실적개월수_기본_24M_카드    int64       0      22       0.0  2.400000e+01
# 391         신청건수_ATM_CA_B0    int64       0       4       0.0  4.000000e+00
# 392         신청건수_ATM_CL_B0    int64       0       2       0.0  3.000000e+00
# 393        신청건수_ATM_CA_R6M    int64       0      22       0.0  2.100000e+01
# 394        신청건수_ATM_CL_R6M    int64       0       3       0.0  4.000000e+00
# 395             승인거절건수_B0M    int64       0       4       0.0  5.000000e+00
# 396        승인거절건수_한도초과_B0M    int64       0       2       0.0  2.000000e+00
# 397          승인거절건수_BL_B0M    int64       0       2       0.0  3.000000e+00
# 398        승인거절건수_입력오류_B0M    int64       0       1       0.0  0.000000e+00
# 399          승인거절건수_기타_B0M    int64       0       1       0.0  0.000000e+00
# 400             승인거절건수_R3M    int64       0      11       0.0  1.000000e+01
# 401        승인거절건수_한도초과_R3M    int64       0       5       0.0  6.000000e+00
# 402          승인거절건수_BL_R3M    int64       0       6       0.0  9.000000e+00
# 403        승인거절건수_입력오류_R3M    int64       0       2       0.0  1.000000e+00
# 404          승인거절건수_기타_R3M    int64       0       3       0.0  2.000000e+00
# 405                  이용금액대   object       0       6       NaN           NaN
#
#             1번째 값
# 0          201807
# 1    TRAIN_000000
# 2        20180719
# 3        20180713
# 4        20180719
# 5             미이용
# 6        20180203
# 7        20180709
# 8        20180713
# 9              11
# 10              9
# 11              8
# 12              1
# 13              0
# 14              1
# 15              0
# 16              2
# 17              0
# 18              0
# 19           1995
# 20              0
# 21              0
# 22              0
# 23              0
# 24          12209
# 25              0
# 26              0
# 27              0
# 28              0
# 29              0
# 30              2
# 31              7
# 32              2
# 33             12
# 34              0
# 35              5
# 36             12
# 37            165
# 38            146
# 39            143
# 40              3
# 41              0
# 42              3
# 43              0
# 44             19
# 45             30
# 46              0
# 47          20667
# 48           9431
# 49           3602
# 50           5828
# 51              0
# 52         103812
# 53           6474
# 54              0
# 55           4906
# 56              0
# 57              0
# 58              0
# 59              0
# 60          11710
# 61           1020
# 62              0
# 63             12
# 64             12
# 65             12
# 66              5
# 67              1
# 68              4
# 69              0
# 70             12
# 71              3
# 72              0
# 73             77
# 74             67
# 75             64
# 76              3
# 77              0
# 78              3
# 79              0
# 80             10
# 81             22
# 82              0
# 83           8380
# 84          -1654
# 85              0
# 86          -1654
# 87              0
# 88          59452
# 89           4090
# 90              0
# 91              6
# 92              6
# 93              6
# 94              2
# 95              0
# 96              2
# 97              0
# 98              6
# 99              1
# 100             0
# 101            27
# 102            22
# 103            21
# 104             1
# 105             0
# 106             1
# 107             0
# 108             5
# 109             0
# 110             0
# 111          2877
# 112          1949
# 113             0
# 114          1984
# 115           -34
# 116         37417
# 117             0
# 118             0
# 119             3
# 120             3
# 121             3
# 122             1
# 123             0
# 124             1
# 125             0
# 126             3
# 127             0
# 128             0
# 129             6
# 130             0
# 131             0
# 132             0
# 133             0
# 134             0
# 135             0
# 136             0
# 137             0
# 138           242
# 139             0
# 140             0
# 141             0
# 142           105
# 143           200
# 144             0
# 145             0
# 146             0
# 147             0
# 148             0
# 149             0
# 150             0
# 151             0
# 152             0
# 153             0
# 154             0
# 155             0
# 156             0
# 157          1883
# 158             0
# 159             0
# 160            44
# 161            납부
# 162          1928
# 163            쇼핑
# 164          1408
# 165          사교활동
# 166           672
# 167          쇼핑기타
# 168           242
# 169           미이용
# 170             0
# 171           미이용
# 172             0
# 173            택시
# 174           200
# 175         버스지하철
# 176           105
# 177           미이용
# 178             0
# 179           미이용
# 180             0
# 181           미이용
# 182             0
# 183           미이용
# 184             0
# 185           보험료
# 186          1883
# 187          납부기타
# 188            44
# 189           미이용
# 190             0
# 191             0
# 192             3
# 193             0
# 194             0
# 195          4917
# 196          4514
# 197             0
# 198             0
# 199             0
# 200             0
# 201             0
# 202             0
# 203          3602
# 204             0
# 205             0
# 206             0
# 207             0
# 208             3
# 209             0
# 210             0
# 211          1314
# 212          4514
# 213             0
# 214             0
# 215             0
# 216             0
# 217             0
# 218             0
# 219             0
# 220             0
# 221             0
# 222             0
# 223             2
# 224           147
# 225             2
# 226             0
# 227             0
# 228             1
# 229             0
# 230             0
# 231             0
# 232             1
# 233             0
# 234             0
# 235             0
# 236             0
# 237             0
# 238             6
# 239             6
# 240             0
# 241             6
# 242             6
# 243             6
# 244             0
# 245             6
# 246             6
# 247             6
# 248             2
# 249             0
# 250             0
# 251             0
# 252             0
# 253             0
# 254             0
# 255             0
# 256             0
# 257             0
# 258             0
# 259             0
# 260             0
# 261             0
# 262           999
# 263           999
# 264             0
# 265             0
# 266             0
# 267           미이용
# 268           미이용
# 269           0.0
# 270           미이용
# 271             0
# 272             0
# 273             0
# 274             1
# 275             6
# 276           847
# 277         11097
# 278             0
# 279            54
# 280             0
# 281          4131
# 282             0
# 283            17
# 284             0
# 285          4043
# 286             0
# 287             7
# 288             0
# 289             0
# 290             0
# 291             0
# 292             0
# 293             0
# 294             0
# 295             0
# 296             0
# 297             0
# 298             0
# 299             0
# 300             0
# 301             0
# 302             0
# 303             0
# 304             0
# 305             0
# 306             0
# 307             0
# 308             0
# 309             0
# 310             0
# 311             0
# 312             0
# 313             0
# 314             0
# 315             0
# 316             0
# 317             0
# 318             0
# 319             0
# 320             0
# 321             0
# 322             0
# 323             0
# 324             0
# 325             0
# 326             0
# 327             0
# 328             0
# 329             0
# 330             0
# 331             0
# 332             0
# 333             0
# 334             0
# 335             0
# 336             0
# 337             0
# 338             0
# 339             0
# 340             0
# 341             0
# 342             0
# 343             0
# 344             0
# 345             0
# 346             0
# 347             0
# 348             0
# 349             0
# 350             0
# 351             0
# 352             0
# 353             0
# 354             0
# 355             0
# 356             0
# 357             0
# 358             0
# 359             0
# 360             0
# 361             1
# 362          1373
# 363             0
# 364             0
# 365             0
# 366             0
# 367             6
# 368             3
# 369             6
# 370             3
# 371             0
# 372             0
# 373         14440
# 374             0
# 375          6335
# 376          8104
# 377         16524
# 378             0
# 379         16125
# 380           398
# 381         14958
# 382             0
# 383          9205
# 384          5752
# 385             0
# 386             0
# 387             0
# 388             0
# 389             0
# 390            13
# 391             0
# 392             0
# 393            11
# 394             0
# 395             0
# 396             0
# 397             0
# 398             0
# 399             0
# 400             3
# 401             3
# 402             0
# 403             0
# 404             0
# 405     01.100만원+

# %%
# 결측치 제거된 컬럼 저장
combined_df.to_csv('train_3_매출정보.csv', index=False, encoding='utf-8-sig')
